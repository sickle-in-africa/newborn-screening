# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math
import matplotlib.pyplot as plt
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Preliminary phase data
df_gh1 = pd.read_csv('../data/raw/ghana/raw/prelims.csv')
df_ml1 = pd.read_csv('../data/raw/mali/raw/prelims.csv', sep=',')
df_tn1 = pd.read_csv('../data/raw/tanzania/raw/tanzania_prelim.csv')
df_ug1 = pd.read_csv('../data/raw/uganda/raw/prelims.csv')
df_zim1 = pd.read_csv('../data/raw/zim_zam/raw/zim.csv')
df_zam1 = pd.read_csv('../data/raw/zim_zam/raw/zam.csv')
df_zim_zam1 = pd.concat([df_zam1, df_zim1], ignore_index=True)

print('df_gh1:', df_gh1.shape)
print('df_ml1:', df_ml1.shape)
print('df_tn1:', df_tn1.shape)
print('df_ug2:', df_ug1.shape)
print('df_zim_zam1:', df_zim_zam1.shape)
# Out:
# df_gh1: (101, 82)
# df_ml1: (104, 219)
# df_tn1: (100, 52)
# df_ug2: (154, 94)
# df_zim_zam1: (200, 17)

# %%
#Quantitative phase data
df_gh2 = pd.read_csv('../data/raw/ghana/raw/ghana_phase_2.csv')
df_ml2 = pd.read_csv('../data/raw/mali/raw/mali_phase_2.csv', sep=';')
df_tn2 = pd.read_csv('../data/raw/tanzania/raw/tanzania_phase_2.csv')
df_ug2 = pd.read_csv('../data/raw/uganda/raw/uganda_phase_2.csv')
df_zim2 = pd.read_csv('../data/raw/zim_zam/raw/zim_phase_2.csv')
df_zam2 = pd.read_csv('../data/raw/zim_zam/raw/zam_phase_2.csv')
df_zim_zam2 = pd.concat([df_zam2, df_zim2], ignore_index=True)

print('df_gh2:', df_gh2.shape)
print('df_ml2:', df_ml2.shape)
print('df_tn2:', df_tn2.shape)
print('df_ug2:', df_ug2.shape)
print('df_zim_zam2:', df_zim_zam2.shape)
# Out:
# df_gh2: (999, 89)
# df_ml2: (104, 219)
# df_tn2: (900, 52)
# df_ug2: (980, 88)
# df_zim_zam2: (1000, 47)

# %%
df_gh2.shape[0]+df_ml2.shape[0]+df_tn2.shape[0]+df_ug2.shape[0]+df_zim_zam2.shape[0]
# Out:
# 3983

# %%
df_gh2.head(2)
# Out:
#    record_id facility_id_screening  nbs_screening_locale participant_id  \
# 0          1                 GH001                     1          ML001
# 1          2                 GH001                     1          ML002
#
#   date_enrolled date_of_visit dob_guardian  pgage_yrs  sex_guardian  \
# 0    20 02 2024    20 02 2024   12 10 1996        NaN             1
# 1    20 02 2024    20 02 2024          NaN        NaN             1
#
#   tribe_guardian  guardian_relationship  specify_relationship  \
# 0           Akan                    2.0                   NaN
# 1         Saliga                    2.0                   NaN
#
#    marital_status_guardian  edu_level_guardian specify_edu_level_guardian  \
# 0                      4.0                 3.0                        NaN
# 1                      3.0                 3.0                        NaN
#
#    guardian_occupation alt_guardian_occupation   religion  \
# 0                  5.0              Decorator   Christian
# 1                  5.0             Seamstress     Muslim
#
#    mother_children_count dob_newborn  sex_newborn  detection_at_birth  \
# 0                    1.0  19 02 2024          0.0                 3.0
# 1                    3.0  19 02 2024          1.0                 5.0
#
#    scd_longevity  early_detection_importance  need_immediate_result  \
# 0            2.0                         4.0                    5.0
# 1            2.0                         4.0                    5.0
#
#    enough_poct_info  poct_result_speed  screening_recommendation  \
# 0               5.0                4.0                       5.0
# 1               5.0                3.0                       5.0
#
#    poct_recommendation  dbs_for_validation  proper_treatment  \
# 0                  5.0                 4.0               5.0
# 1                  5.0                 5.0               5.0
#
#    scd_in_the_family  registry_willingness  no_followup_reasons  \
# 0                2.0                   1.0                  1.0
# 1                3.0                   1.0                  1.0
#
#    nofollowup_reason_specified comments screening_date  \
# 0                          NaN       No     20 02 2024
# 1                          NaN       No     20 02 2024
#
#    kind_of_screening_test___1  kind_of_screening_test___2  \
# 0                           1                           0
# 1                           1                           0
#
#    kind_of_screening_test___3  kind_of_screening_test___4  \
# 0                           0                           0
# 1                           0                           0
#
#    kind_of_screening_test___5  kind_of_screening_test___6  alt_screening_test  \
# 0                           0                           0                 NaN
# 1                           0                           0                 NaN
#
#    tests___1  tests___2  tests___3  tests___4  tests___5  std_poct_done  \
# 0          1          1          1          0          0            1.0
# 1          1          1          1          0          0            1.0
#
#   std_poct_test_date std_poct_test_result_date  std_poct_results  \
# 0         20 02 2024                20 02 2024               1.0
# 1         20 02 2024                20 02 2024               3.0
#
#   dbspoct_test_date dbspoct_test_result_date  dbspoct_test_results  \
# 0        20 02 2024               28 03 2024                   1.0
# 1        20 02 2024               28 03 2024                   1.0
#
#   ief_test_date ief_test_result_date  ief_test_results  hplc_test_date  \
# 0    19 03 2024           19 03 2024               1.0             NaN
# 1    19 03 2024           19 03 2024               7.0             NaN
#
#    hplc_result_date  hplc_results  additional_molecular_test  \
# 0               NaN           NaN                        NaN
# 1               NaN           NaN                        NaN
#
#    additional_test_date  add_molecular_result_date  add_molecula_test_results  \
# 0                   NaN                        NaN                        NaN
# 1                   NaN                        NaN                        NaN
#
#    newborn_registryid  reminder_1  reminder1_method___1  reminder1_method___2  \
# 0                 NaN         NaN                     0                     0
# 1                 NaN         NaN                     0                     0
#
#    reminder1_method___3  reminder1_method___4  alt_reminder1_method  \
# 0                     0                     0                   NaN
# 1                     0                     0                   NaN
#
#    reminder1_personnel  reminder_2  reminder2_method___1  \
# 0                  NaN         NaN                     0
# 1                  NaN         NaN                     0
#
#    reminder2_method___2  reminder2_method___3  reminder2_method___4  \
# 0                     0                     0                     0
# 1                     0                     0                     0
#
#    alt_reminder2_method  reminder2_personnel  reminder_3  \
# 0                   NaN                  NaN         NaN
# 1                   NaN                  NaN         NaN
#
#    reminder3_method___1  reminder3_method___2  reminder3_method___3  \
# 0                     0                     0                     0
# 1                     0                     0                     0
#
#    reminder3_method___4  alt_reminder3_method  reminder3_personnel  \
# 0                     0                   NaN                  NaN
# 1                     0                   NaN                  NaN
#
#    subject_comments
# 0               NaN
# 1               NaN

# %%
mapp = {
    'record_id': ['record_id', 'StudyID'],
    'facility_id': ['facility_id_screening', 'Facility ID'],
    'participant_id': ['participant_id', 'Study participant ID'],
    'date_enrolled': ['date_enrolled', 'Date subject signed consent (DD-MM-YY)'],
    'date_of_visit': ['date_of_visit', 'Date of visit'],
    'dob_guardian': ['dob_guardian', 'Date of birth (D-M-Y)'],
    'sex_guardian': ['sex_guardian', 'Sex'],
    'tribe_guardian': ['tribe_guardian', 'Tribe'],
    'guardian_relationship': ['guardian_relationship', 'Relationship of the guardian to the child'],
    'specify_relationship': ['specify_relationship', "If 'Other' please specify the relationship to the child"],
    'marital_status_guardian': ['marital_status_guardian', 'Marital status'],
    'edu_level_guardian': ['edu_level_guardian', 'Highest level of education completed'],
    'specify_edu_level_guardian': ['specify_edu_level_guardian', "If 'Other', please specify"],
    'guardian_occupation': ['guardian_occupation', 'Occupation'],
    'alt_guardian_occupation': ['alt_guardian_occupation', "If 'Other' occupation, please specify"],
    'religion': ['religion', 'Religion'],
    'mother_children_count': ['mother_children_count', 'Number of children of the mother of the newborn'],
    'dob_newborn': ['dob_newborn', 'Date of birth (D-M-Y).1'],
    'sex_newborn': ['sex_newborn', 'Sex.1'],
    'detection_at_birth': ['detection_at_birth', 'Sickle cell disease (SCD) can be detected at birth'],
    'scd_longevity': ['scd_longevity', 'People with SCD can live long lives'],
    'early_detection_importance': ['early_detection_importance', 'Early detection of SCD is need to provide adequate care for the affected child'],
    'need_immediate_result': ['need_immediate_result', 'It is important that a test for SCD for my child produces the result immediately'],
    'enough_poct_info': ['enough_poct_info', 'I have access to all the information I need on point of care tests for SCD'],
    'poct_result_speed': ['poct_result_speed', 'The result of a point of care test for SCD is available faster than for other screening methods'],
    'screening_recommendation': ['screening_recommendation', 'I would recommend the screening of babies for SCD at other healthcare facilities'],
    'poct_recommendation': ['poct_recommendation', 'I would recommend the use of point of care tests for SCD at other healthcare facilities'],
    'dbs_for_validation': ['dbs_for_validation', 'Alongside the point of care test, it is acceptable for a dried blood spot sample to be collected for validation'],
    'proper_treatment': ['proper_treatment', 'If someone tests positive for SCD at this healthcare facility it is important that they seek proper medical treatment, either here or at another facility'],
    'scd_in_the_family': ['scd_in_the_family', 'Do you have any family member with SCD?'],
    'registry_willingness': ['registry_willingness', 'If your baby tests positive, would you like to enrol the baby in SCD registry?'],
    'no_followup_reasons': ['no_followup_reasons', 'If your baby tests positive for SCD, would you be able to bring your baby back for follow-up?'],
    'nofollowup_reason_specified': ['nofollowup_reason_specified', "If 'No', please specify"],
    'screening_date': ['screening_date', 'Screening date (D-M-Y)'],
    'standard_poct': ['kind_of_screening_test___1'],
    'dbs_poct': ['kind_of_screening_test___2'],
    'ief': ['kind_of_screening_test___3'],
    'hplc': ['hplc', 'HPLC'],
    'molecular_testing': ['kind_of_screening_test___5'],
    'other': ['kind_of_screening_test___6'],
    'alt_screening_test': ['alt_screening_test'],
    'screening_test_done': ['Kind of screening test done (Please check all that apply)'],
    'std_poct_done': ['std_poct_done', 'Standard POCT done?'],
    'std_poct_test_date': ['std_poct_test_date', 'Date standard POCT test done (D-M-Y)'],
    'std_poct_test_result_date': ['std_poct_test_result_date', 'Date of Standard POCT results (D-M-Y)'],
    'std_poct_results': ['std_poct_results', 'Standard POCT Results'],
    'dbspoct_test_date': ['dbspoct_test_date', 'Date DBS-POCT test done (D-M-Y)'],
    'dbspoct_test_result_date': ['dbspoct_test_result_date', 'Date of DBS-POCT results (D-M-Y)'],
    'dbspoct_test_results': ['dbspoct_test_results', 'DBS-POCT Results'],
    'ief_test_date': ['ief_test_date', 'Date IEF test done (D-M-Y)'],
    'ief_test_result_date': ['ief_test_result_date', 'Date of IEF results (D-M-Y)'],
    'ief_test_results': ['ief_test_results', 'IEF Results'],
    'hplc_test_date': ['hplc_test_date', 'Date HPLC test done (D-M-Y)'],
    'hplc_result_date': ['hplc_result_date', 'Date of HPLC results (D-M-Y)'],
    'hplc_results': ['hplc_results', 'HPLC Results'],
    'additional_molecular_test': ['additional_molecular_test'],
    'additional_test_date': ['additional_test_date', 'Date additional molecular test done (D-M-Y)'],
    'add_molecular_result_date': ['add_molecular_result_date', 'Date of additional molecular results (D-M-Y)'],
    'add_molecula_test_results': ['add_molecula_test_results', 'Additional molecular test results']
}

# %%
df_gh2.head(2)
# Out:
#    record_id facility_id_screening  nbs_screening_locale participant_id  \
# 0          1                 GH001                     1          ML001
# 1          2                 GH001                     1          ML002
#
#   date_enrolled date_of_visit dob_guardian  pgage_yrs  sex_guardian  \
# 0    20 02 2024    20 02 2024   12 10 1996        NaN             1
# 1    20 02 2024    20 02 2024          NaN        NaN             1
#
#   tribe_guardian  guardian_relationship  specify_relationship  \
# 0           Akan                    2.0                   NaN
# 1         Saliga                    2.0                   NaN
#
#    marital_status_guardian  edu_level_guardian specify_edu_level_guardian  \
# 0                      4.0                 3.0                        NaN
# 1                      3.0                 3.0                        NaN
#
#    guardian_occupation alt_guardian_occupation   religion  \
# 0                  5.0              Decorator   Christian
# 1                  5.0             Seamstress     Muslim
#
#    mother_children_count dob_newborn  sex_newborn  detection_at_birth  \
# 0                    1.0  19 02 2024          0.0                 3.0
# 1                    3.0  19 02 2024          1.0                 5.0
#
#    scd_longevity  early_detection_importance  need_immediate_result  \
# 0            2.0                         4.0                    5.0
# 1            2.0                         4.0                    5.0
#
#    enough_poct_info  poct_result_speed  screening_recommendation  \
# 0               5.0                4.0                       5.0
# 1               5.0                3.0                       5.0
#
#    poct_recommendation  dbs_for_validation  proper_treatment  \
# 0                  5.0                 4.0               5.0
# 1                  5.0                 5.0               5.0
#
#    scd_in_the_family  registry_willingness  no_followup_reasons  \
# 0                2.0                   1.0                  1.0
# 1                3.0                   1.0                  1.0
#
#    nofollowup_reason_specified comments screening_date  \
# 0                          NaN       No     20 02 2024
# 1                          NaN       No     20 02 2024
#
#    kind_of_screening_test___1  kind_of_screening_test___2  \
# 0                           1                           0
# 1                           1                           0
#
#    kind_of_screening_test___3  kind_of_screening_test___4  \
# 0                           0                           0
# 1                           0                           0
#
#    kind_of_screening_test___5  kind_of_screening_test___6  alt_screening_test  \
# 0                           0                           0                 NaN
# 1                           0                           0                 NaN
#
#    tests___1  tests___2  tests___3  tests___4  tests___5  std_poct_done  \
# 0          1          1          1          0          0            1.0
# 1          1          1          1          0          0            1.0
#
#   std_poct_test_date std_poct_test_result_date  std_poct_results  \
# 0         20 02 2024                20 02 2024               1.0
# 1         20 02 2024                20 02 2024               3.0
#
#   dbspoct_test_date dbspoct_test_result_date  dbspoct_test_results  \
# 0        20 02 2024               28 03 2024                   1.0
# 1        20 02 2024               28 03 2024                   1.0
#
#   ief_test_date ief_test_result_date  ief_test_results  hplc_test_date  \
# 0    19 03 2024           19 03 2024               1.0             NaN
# 1    19 03 2024           19 03 2024               7.0             NaN
#
#    hplc_result_date  hplc_results  additional_molecular_test  \
# 0               NaN           NaN                        NaN
# 1               NaN           NaN                        NaN
#
#    additional_test_date  add_molecular_result_date  add_molecula_test_results  \
# 0                   NaN                        NaN                        NaN
# 1                   NaN                        NaN                        NaN
#
#    newborn_registryid  reminder_1  reminder1_method___1  reminder1_method___2  \
# 0                 NaN         NaN                     0                     0
# 1                 NaN         NaN                     0                     0
#
#    reminder1_method___3  reminder1_method___4  alt_reminder1_method  \
# 0                     0                     0                   NaN
# 1                     0                     0                   NaN
#
#    reminder1_personnel  reminder_2  reminder2_method___1  \
# 0                  NaN         NaN                     0
# 1                  NaN         NaN                     0
#
#    reminder2_method___2  reminder2_method___3  reminder2_method___4  \
# 0                     0                     0                     0
# 1                     0                     0                     0
#
#    alt_reminder2_method  reminder2_personnel  reminder_3  \
# 0                   NaN                  NaN         NaN
# 1                   NaN                  NaN         NaN
#
#    reminder3_method___1  reminder3_method___2  reminder3_method___3  \
# 0                     0                     0                     0
# 1                     0                     0                     0
#
#    reminder3_method___4  alt_reminder3_method  reminder3_personnel  \
# 0                     0                   NaN                  NaN
# 1                     0                   NaN                  NaN
#
#    subject_comments
# 0               NaN
# 1               NaN

# %%
print("df_gh1:", df_gh1.shape)
print("df_ml1:", df_ml1.shape)
print("df_tn1:", df_tn1.shape)
print("df_ug1:", df_ug1.shape)
print("df_zim_zam1:", df_zim_zam1.shape)
print(' ')
print("df_gh2:", df_gh2.shape)
print("df_ml2:", df_ml2.shape)
print("df_tn2:", df_tn2.shape)
print("df_ug2:", df_ug2.shape)
print("df_zim_zam2:", df_zim_zam2.shape)
# Out:
# df_gh1: (101, 82)
# df_ml1: (104, 219)
# df_tn1: (100, 52)
# df_ug1: (154, 94)
# df_zim_zam1: (200, 17)
#
# df_gh2: (999, 89)
# df_ml2: (104, 219)
# df_tn2: (900, 52)
# df_ug2: (980, 88)
# df_zim_zam2: (1000, 47)

# %%
rename_dict = {alias: key for key, aliases in mapp.items() for alias in aliases}

def harmonize_country(df1, df2, mapp, country_name, prefix):
    # Rename columns
    df1 = df1.rename(columns=rename_dict)
    df2 = df2.rename(columns=rename_dict)
    
    for col in mapp.keys():
        if col not in df1.columns:
            df1[col] = None
        if col not in df2.columns:
            df2[col] = None

    # Restrict to schema
    df1 = df1[list(mapp.keys())]
    df2 = df2[list(mapp.keys())]

    # Add metadata
    df1.loc[:, 'country'] = country_name
    df1.loc[:, 'record_id'] = prefix + df1['record_id'].astype(str)

    df2.loc[:, 'country'] = country_name
    df2['record_id'] = prefix + df2['record_id'].astype(str)

    # Show shapes
    print(f"{country_name} df1:", df1.shape)
    print(f"{country_name} df2:", df2.shape)
    print(' ')

    return df1, df2

# %%
df_gh1, df_gh2 = harmonize_country(df_gh1, df_gh2, mapp, 'Ghana', 'GH')
df_ml1, df_ml2 = harmonize_country(df_ml1, df_ml2, mapp, 'Mali', 'ML')
df_tn1, df_tn2 = harmonize_country(df_tn1, df_tn2, mapp, 'Tanzania', 'TN')
df_ug1, df_ug2 = harmonize_country(df_ug1, df_ug2, mapp, 'Uganda', 'UG')
df_zim_zam1, df_zim_zam2 = harmonize_country(df_zim_zam1, df_zim_zam2, mapp, 'Zimbabwe/Zambia', 'ZZ')
# Out:
# Ghana df1: (101, 60)
# Ghana df2: (999, 60)
#
# Mali df1: (104, 61)
# Mali df2: (104, 61)
#
# Tanzania df1: (100, 60)
# Tanzania df2: (900, 60)
#
# Uganda df1: (154, 60)
# Uganda df2: (980, 60)
#
# Zimbabwe/Zambia df1: (200, 60)
# Zimbabwe/Zambia df2: (1000, 60)

# %%
def drop_duplicate_columns(df):
    # remove duplicate-named columns, keeping the first occurrence
    return df.loc[:, ~df.columns.duplicated(keep='first')]

df_gh1 = drop_duplicate_columns(df_gh1)
df_gh2 = drop_duplicate_columns(df_gh2)

df_ml1 = drop_duplicate_columns(df_ml1)
df_ml2 = drop_duplicate_columns(df_ml2)

df_tn1 = drop_duplicate_columns(df_tn1)
df_tn2 = drop_duplicate_columns(df_tn2)

df_ug1 = drop_duplicate_columns(df_ug1)
df_ug2 = drop_duplicate_columns(df_ug2)

df_zim_zam1 = drop_duplicate_columns(df_zim_zam1)
df_zim_zam2 = drop_duplicate_columns(df_zim_zam2)

# %%
df_phase_1 = pd.concat([df_gh1, df_ml1, df_tn1, df_ug1, df_zim_zam1], axis=0, ignore_index=True)
df_phase_2 = pd.concat([df_gh2, df_ml2, df_tn2, df_ug2, df_zim_zam2], axis=0, ignore_index=True)

print(df_phase_1.shape)
print(df_phase_2.shape)
# Out:
# (659, 60)
# (3983, 60)

# %%
df_phase_2.head()
# Out:
#   record_id facility_id participant_id date_enrolled date_of_visit  \
# 0       GH1       GH001          ML001    20 02 2024    20 02 2024
# 1       GH2       GH001          ML002    20 02 2024    20 02 2024
# 2       GH3       GH001          ML003    20 02 2024    20 02 2024
# 3       GH4       GH001          ML004    20 02 2024    20 02 2024
# 4       GH5       GH001          ML005    21 02 2024    21 02 2024
#
#   dob_guardian sex_guardian tribe_guardian guardian_relationship  \
# 0   12 10 1996            1           Akan                   2.0
# 1          NaN            1         Saliga                   2.0
# 2   28 09 1991            1         Frafra                   2.0
# 3          NaN            1         Fulani                   2.0
# 4    1 01 1993            1        Songhai                   2.0
#
#    specify_relationship marital_status_guardian edu_level_guardian  \
# 0                   NaN                     4.0                3.0
# 1                   NaN                     3.0                3.0
# 2                   NaN                     3.0                2.0
# 3                   NaN                     3.0                4.0
# 4                   NaN                     3.0                1.0
#
#   specify_edu_level_guardian guardian_occupation alt_guardian_occupation  \
# 0                        NaN                 5.0              Decorator
# 1                        NaN                 5.0             Seamstress
# 2                        NaN                 5.0             Seamstress
# 3                        NaN                 5.0             Seamstress
# 4                        NaN                 3.0                     NaN
#
#     religion mother_children_count dob_newborn sex_newborn detection_at_birth  \
# 0  Christian                   1.0  19 02 2024         0.0                3.0
# 1    Muslim                    3.0  19 02 2024         1.0                5.0
# 2    Muslim                    2.0  19 02 2024         0.0                3.0
# 3    Muslim                    1.0   9 01 2024         1.0                5.0
# 4     Muslim                   7.0  21 02 2024         0.0                4.0
#
#   scd_longevity early_detection_importance need_immediate_result  \
# 0           2.0                        4.0                   5.0
# 1           2.0                        4.0                   5.0
# 2           2.0                        4.0                   5.0
# 3           4.0                        5.0                   2.0
# 4           3.0                        3.0                   3.0
#
#   enough_poct_info poct_result_speed screening_recommendation  \
# 0              5.0               4.0                      5.0
# 1              5.0               3.0                      5.0
# 2              5.0               5.0                      5.0
# 3              5.0               4.0                      5.0
# 4              4.0               4.0                      4.0
#
#   poct_recommendation dbs_for_validation proper_treatment scd_in_the_family  \
# 0                 5.0                4.0              5.0               2.0
# 1                 5.0                5.0              5.0               3.0
# 2                 5.0                4.0              5.0               2.0
# 3                 5.0                5.0              5.0               2.0
# 4                 4.0                4.0              4.0               2.0
#
#   registry_willingness no_followup_reasons nofollowup_reason_specified  \
# 0                  1.0                 1.0                         NaN
# 1                  1.0                 1.0                         NaN
# 2                  1.0                 1.0                         NaN
# 3                  1.0                 1.0                         NaN
# 4                  1.0                 1.0                         NaN
#
#   screening_date standard_poct dbs_poct ief  hplc molecular_testing other  \
# 0     20 02 2024             1        0   0  None                 0     0
# 1     20 02 2024             1        0   0  None                 0     0
# 2     20 02 2024             1        0   0  None                 0     0
# 3     20 02 2024             1        0   0  None                 0     0
# 4     21 02 2024             1        0   0  None                 0     0
#
#   alt_screening_test screening_test_done std_poct_done std_poct_test_date  \
# 0                NaN                None           1.0         20 02 2024
# 1                NaN                None           1.0         20 02 2024
# 2                NaN                None           1.0         20 02 2024
# 3                NaN                None           1.0         20 02 2024
# 4                NaN                None           1.0         21 02 2024
#
#   std_poct_test_result_date std_poct_results dbspoct_test_date  \
# 0                20 02 2024              1.0        20 02 2024
# 1                20 02 2024              3.0        20 02 2024
# 2                20 02 2024              1.0        22 02 2024
# 3                20 02 2024              2.0        20 02 2024
# 4                21 02 2024              1.0        21 02 2024
#
#   dbspoct_test_result_date  dbspoct_test_results ief_test_date  \
# 0               28 03 2024                   1.0    19 03 2024
# 1               28 03 2024                   1.0    19 03 2024
# 2               28 03 2024                   1.0    13 03 2024
# 3               28 03 2024                   2.0    13 03 2024
# 4               28 03 2024                   1.0    13 03 2024
#
#   ief_test_result_date ief_test_results hplc_test_date hplc_result_date  \
# 0           19 03 2024              1.0            NaN              NaN
# 1           19 03 2024              7.0            NaN              NaN
# 2           13 03 2024              1.0            NaN              NaN
# 3           13 03 2024              6.0            NaN              NaN
# 4           13 03 2024              1.0            NaN              NaN
#
#   hplc_results additional_molecular_test additional_test_date  \
# 0          NaN                       NaN                  NaN
# 1          NaN                       NaN                  NaN
# 2          NaN                       NaN                  NaN
# 3          NaN                       NaN                  NaN
# 4          NaN                       NaN                  NaN
#
#   add_molecular_result_date add_molecula_test_results country
# 0                       NaN                       NaN   Ghana
# 1                       NaN                       NaN   Ghana
# 2                       NaN                       NaN   Ghana
# 3                       NaN                       NaN   Ghana
# 4                       NaN                       NaN   Ghana

# %%
df_phase_2.columns
# Out:
# Index(['record_id', 'facility_id', 'participant_id', 'date_enrolled',
#        'date_of_visit', 'dob_guardian', 'sex_guardian', 'tribe_guardian',
#        'guardian_relationship', 'specify_relationship',
#        'marital_status_guardian', 'edu_level_guardian',
#        'specify_edu_level_guardian', 'guardian_occupation',
#        'alt_guardian_occupation', 'religion', 'mother_children_count',
#        'dob_newborn', 'sex_newborn', 'detection_at_birth', 'scd_longevity',
#        'early_detection_importance', 'need_immediate_result',
#        'enough_poct_info', 'poct_result_speed', 'screening_recommendation',
#        'poct_recommendation', 'dbs_for_validation', 'proper_treatment',
#        'scd_in_the_family', 'registry_willingness', 'no_followup_reasons',
#        'nofollowup_reason_specified', 'screening_date', 'standard_poct',
#        'dbs_poct', 'ief', 'hplc', 'molecular_testing', 'other',
#        'alt_screening_test', 'screening_test_done', 'std_poct_done',
#        'std_poct_test_date', 'std_poct_test_result_date', 'std_poct_results',
#        'dbspoct_test_date', 'dbspoct_test_result_date', 'dbspoct_test_results',
#        'ief_test_date', 'ief_test_result_date', 'ief_test_results',
#        'hplc_test_date', 'hplc_result_date', 'hplc_results',
#        'additional_molecular_test', 'additional_test_date',
#        'add_molecular_result_date', 'add_molecula_test_results', 'country'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Count missing values in each column
missing_summary = df_phase_2.isnull().sum()

# Filter for columns with missing values
missing_summary = missing_summary[missing_summary > 0].sort_values(ascending=False)

# Create a color gradient (blue shades)
colors = plt.cm.Blues(np.linspace(0.6, 1, len(missing_summary)))

# Adjust figure size for more vertical space
plt.figure(figsize=(14, 12))  # Increased height

# Plot missing values as a horizontal bar chart
missing_summary.plot(kind='barh', color=colors, width=0.8)  # Thicker bars

# Modern styling
plt.title('Missing Values Per Column', fontsize=14)
plt.xlabel('Number of Missing Values', fontsize=12)
plt.ylabel('Columns', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Remove top and right borders
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Remove borders around bars
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['bottom'].set_color('#cccccc')  # Light gray bottom border for subtle styling

# Improve layout
plt.tight_layout()

# Save the plot as a file
plt.savefig("figures/eda/missing_values_plot.png", dpi=300, bbox_inches='tight')  # Save as PNG with high resolution

# Show the plot
plt.show()

# %%
# List of questionnaire-related variables
questionnaire_vars = [
    'dob_guardian','sex_guardian','guardian_relationship', 'detection_at_birth', 'scd_longevity', 
    'early_detection_importance','need_immediate_result', 'enough_poct_info', 'poct_result_speed',
    'screening_recommendation', 'poct_recommendation', 'dbs_for_validation',
    'proper_treatment', 'scd_in_the_family', 'registry_willingness',
    'no_followup_reasons', 'nofollowup_reason_specified', 'screening_date'
]

# Add 'country' and 'facility_id' to the list
columns_to_keep = questionnaire_vars + ['country', 'facility_id','participant_id', 'record_id']

# Filter the DataFrame
df_questionnaire = df_phase_2[columns_to_keep]

column_order = [
    'record_id', 'participant_id', 'facility_id','screening_date', 'dob_guardian','sex_guardian', 'guardian_relationship',
    'detection_at_birth', 'scd_longevity', 'early_detection_importance',
    'need_immediate_result', 'enough_poct_info', 'poct_result_speed',
    'screening_recommendation', 'poct_recommendation', 'dbs_for_validation',
    'proper_treatment', 'scd_in_the_family', 'registry_willingness',
    'no_followup_reasons', 'nofollowup_reason_specified', 'country'
]

# Reorder columns in the DataFrame
df_questionnaire = df_questionnaire[column_order]

# Display the shape and first few rows of the new DataFrame
print('Filtered DataFrame shape:', df_questionnaire.shape)
# Out:
# Filtered DataFrame shape: (3983, 22)

# %%
print('Filtered DataFrame shape:', df_questionnaire.shape)
df_questionnaire.head()
# Out:
# Filtered DataFrame shape: (3983, 22)
#   record_id participant_id facility_id screening_date dob_guardian  \
# 0       GH1          ML001       GH001     20 02 2024   12 10 1996
# 1       GH2          ML002       GH001     20 02 2024          NaN
# 2       GH3          ML003       GH001     20 02 2024   28 09 1991
# 3       GH4          ML004       GH001     20 02 2024          NaN
# 4       GH5          ML005       GH001     21 02 2024    1 01 1993
#
#   sex_guardian guardian_relationship detection_at_birth scd_longevity  \
# 0            1                   2.0                3.0           2.0
# 1            1                   2.0                5.0           2.0
# 2            1                   2.0                3.0           2.0
# 3            1                   2.0                5.0           4.0
# 4            1                   2.0                4.0           3.0
#
#   early_detection_importance need_immediate_result enough_poct_info  \
# 0                        4.0                   5.0              5.0
# 1                        4.0                   5.0              5.0
# 2                        4.0                   5.0              5.0
# 3                        5.0                   2.0              5.0
# 4                        3.0                   3.0              4.0
#
#   poct_result_speed screening_recommendation poct_recommendation  \
# 0               4.0                      5.0                 5.0
# 1               3.0                      5.0                 5.0
# 2               5.0                      5.0                 5.0
# 3               4.0                      5.0                 5.0
# 4               4.0                      4.0                 4.0
#
#   dbs_for_validation proper_treatment scd_in_the_family registry_willingness  \
# 0                4.0              5.0               2.0                  1.0
# 1                5.0              5.0               3.0                  1.0
# 2                4.0              5.0               2.0                  1.0
# 3                5.0              5.0               2.0                  1.0
# 4                4.0              4.0               2.0                  1.0
#
#   no_followup_reasons nofollowup_reason_specified country
# 0                 1.0                         NaN   Ghana
# 1                 1.0                         NaN   Ghana
# 2                 1.0                         NaN   Ghana
# 3                 1.0                         NaN   Ghana
# 4                 1.0                         NaN   Ghana

# %%
df_questionnaire.shape
# Out:
# (3983, 22)

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Count missing values in each column
# missing_summary = df_questionnaire.isnull().sum()

# # Filter for columns with missing values
# missing_summary = missing_summary[missing_summary > 0].sort_values(ascending=False)

# # Create a color gradient (blue shades)
# colors = plt.cm.Blues(np.linspace(0.6, 1, len(missing_summary)))

# # Adjust figure size for more vertical space
# plt.figure(figsize=(14, 12))  # Increased height

# # Plot missing values as a horizontal bar chart
# missing_summary.plot(kind='barh', color=colors, width=0.8)  # Thicker bars

# # Modern styling
# plt.title('Missing Values Per Questionnaire Column (Guardian)', fontsize=14)
# plt.xlabel('Number of Missing Values', fontsize=12)
# plt.ylabel('Columns', fontsize=12)
# plt.xticks(fontsize=10)
# plt.yticks(fontsize=10)

# # Remove top and right borders
# plt.gca().spines['top'].set_visible(False)
# plt.gca().spines['right'].set_visible(False)

# # Remove borders around bars
# plt.gca().spines['left'].set_visible(False)
# plt.gca().spines['bottom'].set_color('#cccccc')  # Light gray bottom border for subtle styling

# # Improve layout
# plt.tight_layout()

# # Save the plot as a file
# plt.savefig("figures/eda/missing_values_questionnaire.png", dpi=300, bbox_inches='tight')  # Save as PNG with high resolution

# # Show the plot
# plt.show()

# %%
df_questionnaire.shape
# Out:
# (3983, 22)

# %%
df_questionnaire.head()
# Out:
#   record_id participant_id facility_id screening_date dob_guardian  \
# 0       GH1          ML001       GH001     20 02 2024   12 10 1996
# 1       GH2          ML002       GH001     20 02 2024          NaN
# 2       GH3          ML003       GH001     20 02 2024   28 09 1991
# 3       GH4          ML004       GH001     20 02 2024          NaN
# 4       GH5          ML005       GH001     21 02 2024    1 01 1993
#
#   sex_guardian guardian_relationship detection_at_birth scd_longevity  \
# 0            1                   2.0                3.0           2.0
# 1            1                   2.0                5.0           2.0
# 2            1                   2.0                3.0           2.0
# 3            1                   2.0                5.0           4.0
# 4            1                   2.0                4.0           3.0
#
#   early_detection_importance need_immediate_result enough_poct_info  \
# 0                        4.0                   5.0              5.0
# 1                        4.0                   5.0              5.0
# 2                        4.0                   5.0              5.0
# 3                        5.0                   2.0              5.0
# 4                        3.0                   3.0              4.0
#
#   poct_result_speed screening_recommendation poct_recommendation  \
# 0               4.0                      5.0                 5.0
# 1               3.0                      5.0                 5.0
# 2               5.0                      5.0                 5.0
# 3               4.0                      5.0                 5.0
# 4               4.0                      4.0                 4.0
#
#   dbs_for_validation proper_treatment scd_in_the_family registry_willingness  \
# 0                4.0              5.0               2.0                  1.0
# 1                5.0              5.0               3.0                  1.0
# 2                4.0              5.0               2.0                  1.0
# 3                5.0              5.0               2.0                  1.0
# 4                4.0              4.0               2.0                  1.0
#
#   no_followup_reasons nofollowup_reason_specified country
# 0                 1.0                         NaN   Ghana
# 1                 1.0                         NaN   Ghana
# 2                 1.0                         NaN   Ghana
# 3                 1.0                         NaN   Ghana
# 4                 1.0                         NaN   Ghana

# %%
for col in df_questionnaire.columns:
    print(f"Column: {col}")
    print(df_questionnaire[col].value_counts(dropna=False))
    print("-" * 40)  # Separator for readability
# Out:
# Column: record_id
# record_id
# ZZnan        100
# TN900          2
# GH1            1
# UG1550         1
# UG1552         1
# UG1513         1
# UG1514         1
# UG1515         1
# UG1516         1
# UG1517         1
# UG1518         1
# UG928          1
# UG929          1
# UG930          1
# UG931          1
# UG932          1
# UG949          1
# UG933          1
# UG934          1
# UG936          1
# UG937          1
# UG938          1
# UG939          1
# UG940          1
# UG941          1
# UG942          1
# UG943          1
# UG944          1
# UG945          1
# UG947          1
# UG1548         1
# UG1549         1
# UG1547         1
# UG1546         1
# UG1520         1
# UG1521         1
# UG1522         1
# UG1523         1
# UG1524         1
# UG1529         1
# UG1525         1
# UG1526         1
# UG1527         1
# UG1528         1
# UG1530         1
# UG1532         1
# UG1531         1
# UG1533         1
# UG1534         1
# UG1535         1
# UG1540         1
# UG1541         1
# UG1536         1
# UG1537         1
# UG1538         1
# UG1539         1
# UG1939         1
# UG1542         1
# UG1543         1
# UG1544         1
# UG1545         1
# UG948          1
# UG950          1
# UG1587         1
# UG1017         1
# UG1003         1
# UG1005         1
# UG1006         1
# UG1007         1
# UG1008         1
# UG1009         1
# UG1010         1
# UG1011         1
# UG1013         1
# UG1014         1
# UG1015         1
# UG1016         1
# UG1018         1
# UG1000         1
# UG1019         1
# UG1020         1
# UG1021         1
# UG1022         1
# UG1024         1
# UG1025         1
# UG1026         1
# UG1494         1
# UG1495         1
# UG1496         1
# UG1497         1
# UG1498         1
# UG1002         1
# UG999          1
# UG951          1
# UG967          1
# UG952          1
# UG953          1
# UG954          1
# UG955          1
# UG958          1
# UG959          1
# UG960          1
# UG961          1
# UG962          1
# UG964          1
# UG965          1
# UG966          1
# UG981          1
# UG997          1
# UG982          1
# UG983          1
# UG984          1
# UG986          1
# UG987          1
# UG988          1
# UG991          1
# UG992          1
# UG993          1
# UG994          1
# UG995          1
# UG996          1
# UG1519         1
# UG1585         1
# UG1586         1
# UG1500         1
# UG895          1
# UG896          1
# UG897          1
# UG898          1
# UG899          1
# UG900          1
# UG901          1
# UG902          1
# UG904          1
# UG905          1
# UG906          1
# UG907          1
# UG908          1
# UG909          1
# UG910          1
# UG911          1
# UG912          1
# UG913          1
# UG915          1
# UG916          1
# UG917          1
# UG918          1
# UG919          1
# UG920          1
# UG921          1
# UG177          1
# UG187          1
# UG894          1
# UG893          1
# UG891          1
# UG263          1
# UG1599         1
# UG1600         1
# UG1601         1
# UG1602         1
# UG1603         1
# UG1604         1
# UG188          1
# UG189          1
# UG190          1
# UG191          1
# UG192          1
# UG193          1
# UG194          1
# UG889          1
# UG195          1
# UG178          1
# UG179          1
# UG1605         1
# UG1606         1
# UG882          1
# UG884          1
# UG883          1
# UG885          1
# UG886          1
# UG887          1
# UG888          1
# UG922          1
# UG923          1
# UG924          1
# UG1572         1
# UG1559         1
# UG1560         1
# UG1561         1
# UG1562         1
# UG1563         1
# UG1564         1
# UG1565         1
# UG1567         1
# UG1566         1
# UG1568         1
# UG1569         1
# UG1570         1
# UG1571         1
# UG1557         1
# UG1573         1
# UG1574         1
# UG1575         1
# UG1576         1
# UG1577         1
# UG1578         1
# UG1579         1
# UG1580         1
# UG1581         1
# UG1582         1
# UG1583         1
# UG1584         1
# UG1558         1
# UG1556         1
# UG926          1
# UG1399         1
# UG927          1
# UG1377         1
# UG1378         1
# UG1379         1
# UG1380         1
# UG1381         1
# UG1382         1
# UG1384         1
# UG1385         1
# UG1396         1
# UG1397         1
# UG1398         1
# UG1400         1
# UG1555         1
# UG1401         1
# UG1402         1
# UG1403         1
# UG1404         1
# UG1405         1
# UG1406         1
# UG1407         1
# UG1408         1
# UG1409         1
# UG1410         1
# UG1553         1
# UG1554         1
# UG1499         1
# UG1501         1
# UG225          1
# UG1685         1
# UG1351         1
# UG1352         1
# UG1353         1
# UG1354         1
# UG1355         1
# UG1356         1
# UG1357         1
# UG1358         1
# UG1607         1
# UG1608         1
# UG1609         1
# UG1610         1
# UG1611         1
# UG1670         1
# UG1671         1
# UG1672         1
# UG1673         1
# UG1674         1
# UG1675         1
# UG1676         1
# UG1677         1
# UG1678         1
# UG1679         1
# UG1680         1
# UG1681         1
# UG1682         1
# UG1683         1
# UG1350         1
# UG1349         1
# UG1348         1
# UG1333         1
# UG1315         1
# UG1316         1
# UG1317         1
# UG1318         1
# UG1319         1
# UG1320         1
# UG1327         1
# UG1328         1
# UG1329         1
# UG1330         1
# UG1331         1
# UG1332         1
# UG1334         1
# UG1347         1
# UG1335         1
# UG1336         1
# UG1337         1
# UG1338         1
# UG1339         1
# UG1340         1
# UG1341         1
# UG1342         1
# UG1343         1
# UG1344         1
# UG1345         1
# UG1346         1
# UG1684         1
# UG1686         1
# UG1502         1
# UG1687         1
# UG1740         1
# UG1910         1
# UG1911         1
# UG1912         1
# UG1913         1
# UG1962         1
# UG1963         1
# UG1775         1
# UG1776         1
# UG1777         1
# UG1778         1
# UG1779         1
# UG1780         1
# UG1781         1
# UG1782         1
# UG1783         1
# UG1991         1
# UG1809         1
# UG1810         1
# UG1811         1
# UG1812         1
# UG1813         1
# UG1814         1
# UG1815         1
# UG1816         1
# UG1817         1
# UG1818         1
# UG1739         1
# UG1738         1
# UG1737         1
# UG1722         1
# UG1688         1
# UG1690         1
# UG1712         1
# UG1713         1
# UG1714         1
# UG1715         1
# UG1716         1
# UG1717         1
# UG1718         1
# UG1719         1
# UG1720         1
# UG1721         1
# UG1723         1
# UG1736         1
# UG1724         1
# UG1725         1
# UG1726         1
# UG1727         1
# UG1728         1
# UG1729         1
# UG1730         1
# UG1731         1
# UG1732         1
# UG1733         1
# UG1734         1
# UG1735         1
# UG1314         1
# UG1313         1
# UG1312         1
# UG1311         1
# UG1630         1
# UG1631         1
# UG1632         1
# UG1634         1
# UG1635         1
# UG1636         1
# UG1637         1
# UG1638         1
# UG1639         1
# UG1640         1
# UG1641         1
# UG1642         1
# UG1643         1
# UG1655         1
# UG1656         1
# UG1657         1
# UG1658         1
# UG1659         1
# UG1660         1
# UG1661         1
# UG1662         1
# UG1663         1
# UG1664         1
# UG1904         1
# UG1905         1
# UG1906         1
# UG1909         1
# UG1633         1
# UG1629         1
# UG1627         1
# UG1612         1
# UG1503         1
# UG1504         1
# UG1505         1
# UG1506         1
# UG1507         1
# UG1508         1
# UG1509         1
# UG1510         1
# UG1511         1
# UG1512         1
# UG1296         1
# UG1297         1
# UG1613         1
# UG1628         1
# UG1614         1
# UG1616         1
# UG1617         1
# UG1618         1
# UG1619         1
# UG1620         1
# UG1621         1
# UG1622         1
# UG1623         1
# UG1624         1
# UG1625         1
# UG1626         1
# UG1907         1
# UG1908         1
# UG1898         1
# UG1975         1
# UG1984         1
# UG1985         1
# UG1986         1
# UG1938         1
# UG1988         1
# UG1989         1
# UG1990         1
# UG1970         1
# UG1971         1
# UG1972         1
# UG1973         1
# UG1974         1
# UG1976         1
# UG1981         1
# UG1977         1
# UG2058         1
# UG2057         1
# UG2055         1
# UG2056         1
# UG1298         1
# UG1299         1
# UG1306         1
# UG1307         1
# UG1308         1
# UG1309         1
# UG1310         1
# UG1983         1
# UG1982         1
# UG2039         1
# UG1969         1
# UG1899         1
# UG1900         1
# UG1901         1
# UG1902         1
# UG1965         1
# UG1951         1
# UG1952         1
# UG1954         1
# UG1955         1
# UG1953         1
# UG1956         1
# UG1966         1
# UG1968         1
# UG1997         1
# UG1967         1
# UG1992         1
# UG2052         1
# UG2053         1
# UG2033         1
# UG2034         1
# UG2035         1
# UG2036         1
# UG1993         1
# UG1994         1
# UG1995         1
# UG1996         1
# UG226          1
# UG223          1
# UG224          1
# UG1284         1
# UG109          1
# UG110          1
# UG112          1
# UG107          1
# UG108          1
# UG111          1
# UG113          1
# UG114          1
# UG1068         1
# UG1282         1
# UG1293         1
# UG1303         1
# UG1304         1
# UG258          1
# UG892          1
# UG291          1
# UG1449         1
# UG280          1
# UG302          1
# UG269          1
# UG313          1
# UG247          1
# UG1474         1
# UG1305         1
# UG216          1
# UG1424         1
# UG1458         1
# UG88           1
# UG87           1
# UG86           1
# UG57           1
# UG45           1
# UG998          1
# UG46           1
# UG47           1
# UG48           1
# UG49           1
# UG50           1
# UG51           1
# UG52           1
# UG53           1
# UG55           1
# UG56           1
# UG58           1
# UG85           1
# UG59           1
# UG60           1
# UG61           1
# UG105          1
# UG102          1
# UG79           1
# UG103          1
# UG81           1
# UG82           1
# UG104          1
# UG83           1
# UG84           1
# UG1283         1
# UG1285         1
# UG1964         1
# UG1286         1
# UG1325         1
# UG1326         1
# UG1489         1
# UG1490         1
# UG1491         1
# UG1492         1
# UG1482         1
# UG1483         1
# UG1484         1
# UG1485         1
# UG1486         1
# UG1487         1
# UG259          1
# UG260          1
# UG261          1
# UG262          1
# UG264          1
# UG265          1
# UG266          1
# UG267          1
# UG268          1
# UG1488         1
# UG1475         1
# UG1476         1
# UG1477         1
# UG1478         1
# UG1479         1
# UG1324         1
# UG1323         1
# UG1322         1
# UG1023         1
# UG1287         1
# UG1288         1
# UG1289         1
# UG1290         1
# UG1291         1
# UG1292         1
# UG1294         1
# UG1295         1
# UG1300         1
# UG1301         1
# UG1001         1
# UG1012         1
# UG1027         1
# UG1321         1
# UG1029         1
# UG1028         1
# UG1030         1
# UG1031         1
# UG1032         1
# UG1034         1
# UG1035         1
# UG1037         1
# UG1038         1
# UG1036         1
# UG1302         1
# UG1493         1
# UG44           1
# UG68           1
# UG67           1
# UG66           1
# TN978          1
# TN979          1
# TN980          1
# TN981          1
# TN982          1
# TN983          1
# TN984          1
# TN985          1
# TN986          1
# TN987          1
# TN988          1
# TN989          1
# TN990          1
# TN991          1
# TN992          1
# TN993          1
# TN994          1
# TN995          1
# TN996          1
# TN997          1
# TN998          1
# TN999          1
# TN1000         1
# TN1001         1
# TN1002         1
# TN1003         1
# TN1004         1
# TN977          1
# TN976          1
# TN975          1
# TN960          1
# TN948          1
# TN949          1
# TN950          1
# TN951          1
# TN952          1
# TN953          1
# TN954          1
# TN955          1
# TN956          1
# TN957          1
# TN958          1
# TN959          1
# TN961          1
# TN974          1
# TN962          1
# TN963          1
# TN964          1
# TN965          1
# TN966          1
# TN967          1
# TN968          1
# TN969          1
# TN970          1
# TN971          1
# TN972          1
# TN973          1
# TN1005         1
# UG890          1
# UG176          1
# UG98           1
# UG24           1
# UG25           1
# UG27           1
# UG54           1
# UG28           1
# UG29           1
# UG30           1
# UG77           1
# UG31           1
# UG32           1
# UG34           1
# UG35           1
# UG78           1
# UG42           1
# UG99           1
# UG100          1
# UG101          1
# UG72           1
# UG73           1
# UG74           1
# UG75           1
# UG26           1
# UG62           1
# UG63           1
# UG64           1
# UG65           1
# UG23           1
# UG38           1
# UG80           1
# UG91           1
# UG95           1
# UG22           1
# UG69           1
# UG106          1
# UG115          1
# UG33           1
# UG36           1
# UG117          1
# UG116          1
# UG89           1
# UG118          1
# UG90           1
# UG119          1
# UG40           1
# UG120          1
# UG121          1
# UG37           1
# UG96           1
# UG92           1
# UG93           1
# UG97           1
# UG94           1
# UG70           1
# UG71           1
# UG39           1
# UG41           1
# UG1480         1
# UG1481         1
# UG1468         1
# UG1427         1
# UG1100         1
# UG1101         1
# UG1102         1
# UG1103         1
# UG1104         1
# UG1105         1
# UG1106         1
# UG1107         1
# UG1108         1
# UG1109         1
# UG871          1
# UG872          1
# UG873          1
# UG874          1
# UG875          1
# UG876          1
# UG877          1
# UG878          1
# UG879          1
# UG880          1
# UG180          1
# UG181          1
# UG182          1
# UG183          1
# UG185          1
# UG186          1
# UG1592         1
# UG1039         1
# UG1098         1
# UG1097         1
# UG1080         1
# UG1426         1
# UG1423         1
# UG1425         1
# UG1429         1
# UG1936         1
# UG315          1
# UG316          1
# UG317          1
# UG318          1
# UG319          1
# UG320          1
# UG321          1
# UG1081         1
# UG1096         1
# UG1082         1
# UG1084         1
# UG1085         1
# UG1086         1
# UG1089         1
# UG1087         1
# UG1090         1
# UG1091         1
# UG1092         1
# UG1093         1
# UG1094         1
# UG1095         1
# UG1594         1
# UG1593         1
# UG1595         1
# UG308          1
# UG295          1
# UG296          1
# UG297          1
# UG298          1
# UG299          1
# UG300          1
# UG301          1
# UG303          1
# UG304          1
# UG305          1
# UG306          1
# UG307          1
# UG309          1
# UG293          1
# UG310          1
# UG311          1
# UG312          1
# UG314          1
# UG322          1
# UG323          1
# UG217          1
# UG218          1
# UG219          1
# UG220          1
# UG221          1
# UG222          1
# UG294          1
# UG292          1
# UG1596         1
# UG1366         1
# UG1597         1
# UG1598         1
# UG1588         1
# UG1359         1
# UG1589         1
# UG1590         1
# UG1360         1
# UG1364         1
# UG1362         1
# UG1361         1
# UG1363         1
# UG1365         1
# UG1367         1
# UG290          1
# UG1369         1
# UG1370         1
# UG1371         1
# UG1372         1
# UG1373         1
# UG1591         1
# UG1374         1
# UG1375         1
# UG1376         1
# UG287          1
# UG288          1
# UG289          1
# UG1422         1
# UG1421         1
# UG1469         1
# UG1439         1
# UG946          1
# UG957          1
# UG990          1
# UG227          1
# UG228          1
# UG229          1
# UG230          1
# UG231          1
# UG232          1
# UG233          1
# UG234          1
# UG235          1
# UG237          1
# UG238          1
# UG239          1
# UG240          1
# UG241          1
# UG242          1
# UG243          1
# UG244          1
# UG245          1
# UG246          1
# UG1040         1
# UG1041         1
# UG1042         1
# UG1043         1
# UG1045         1
# UG935          1
# UG925          1
# UG914          1
# UG1448         1
# UG1470         1
# UG1472         1
# UG1473         1
# UG1459         1
# UG1460         1
# UG1461         1
# UG1462         1
# UG1443         1
# UG1444         1
# UG1445         1
# UG1446         1
# UG1447         1
# UG989          1
# UG903          1
# UG869          1
# UG215          1
# UG1033         1
# UG1044         1
# UG1055         1
# UG1066         1
# UG1077         1
# UG236          1
# UG1088         1
# UG1099         1
# UG870          1
# UG881          1
# UG1046         1
# UG1047         1
# UG1048         1
# UG1075         1
# UG274          1
# UG275          1
# UG276          1
# UG277          1
# UG278          1
# UG279          1
# UG1069         1
# UG1070         1
# UG1071         1
# UG1072         1
# UG1073         1
# UG1074         1
# UG1076         1
# UG272          1
# UG1078         1
# UG1079         1
# UG281          1
# UG282          1
# UG283          1
# UG284          1
# UG285          1
# UG286          1
# UG1450         1
# UG1451         1
# UG1452         1
# UG1436         1
# UG273          1
# UG271          1
# UG248          1
# UG1053         1
# UG249          1
# UG250          1
# UG251          1
# UG252          1
# UG253          1
# UG254          1
# UG255          1
# UG256          1
# UG1049         1
# UG1050         1
# UG1051         1
# UG1052         1
# UG1054         1
# UG270          1
# UG1056         1
# UG1057         1
# UG1058         1
# UG257          1
# UG1059         1
# UG1060         1
# UG1061         1
# UG1062         1
# UG1063         1
# UG1064         1
# UG1065         1
# UG1067         1
# UG1819         1
# UG1886         1
# TN946          1
# ZZ249          1
# ZZ221          1
# ZZ222          1
# ZZ223          1
# ZZ224          1
# ZZ225          1
# ZZ226          1
# ZZ227          1
# ZZ228          1
# ZZ229          1
# ZZ230          1
# ZZ231          1
# ZZ232          1
# ZZ233          1
# ZZ234          1
# ZZ235          1
# ZZ236          1
# ZZ237          1
# ZZ238          1
# ZZ239          1
# ZZ240          1
# ZZ241          1
# ZZ242          1
# ZZ243          1
# ZZ244          1
# ZZ245          1
# ZZ246          1
# ZZ247          1
# ZZ220          1
# ZZ219          1
# ZZ218          1
# ZZ203          1
# ZZ191          1
# ZZ192          1
# ZZ193          1
# ZZ194          1
# ZZ195          1
# ZZ196          1
# ZZ197          1
# ZZ198          1
# ZZ199          1
# ZZ200          1
# ZZ201          1
# ZZ202          1
# ZZ204          1
# ZZ217          1
# ZZ205          1
# ZZ206          1
# ZZ207          1
# ZZ208          1
# ZZ209          1
# ZZ210          1
# ZZ211          1
# ZZ212          1
# ZZ213          1
# ZZ214          1
# ZZ215          1
# ZZ216          1
# ZZ248          1
# ZZ250          1
# ZZ311          1
# ZZ251          1
# ZZ283          1
# ZZ284          1
# ZZ285          1
# ZZ286          1
# ZZ287          1
# ZZ288          1
# ZZ289          1
# ZZ290          1
# ZZ291          1
# ZZ292          1
# ZZ293          1
# ZZ294          1
# ZZ295          1
# ZZ296          1
# ZZ297          1
# ZZ298          1
# ZZ299          1
# ZZ300          1
# ZZ301          1
# ZZ302          1
# ZZ303          1
# ZZ304          1
# ZZ305          1
# ZZ306          1
# ZZ307          1
# ZZ308          1
# ZZ309          1
# ZZ282          1
# ZZ281          1
# ZZ280          1
# ZZ264          1
# ZZ252          1
# ZZ253          1
# ZZ254          1
# ZZ255          1
# ZZ256          1
# ZZ257          1
# ZZ258          1
# ZZ259          1
# ZZ260          1
# ZZ261          1
# ZZ262          1
# ZZ263          1
# ZZ265          1
# ZZ279          1
# ZZ266          1
# ZZ267          1
# ZZ268          1
# ZZ270          1
# ZZ271          1
# ZZ272          1
# ZZ273          1
# ZZ274          1
# ZZ275          1
# ZZ276          1
# ZZ277          1
# ZZ278          1
# ZZ190          1
# ZZ189          1
# ZZ188          1
# ZZ187          1
# ZZ742          1
# ZZ743          1
# ZZ744          1
# ZZ101          1
# ZZ102          1
# ZZ103          1
# ZZ104          1
# ZZ105          1
# ZZ106          1
# ZZ107          1
# ZZ108          1
# ZZ109          1
# ZZ110          1
# ZZ111          1
# ZZ114          1
# ZZ115          1
# ZZ116          1
# ZZ117          1
# ZZ118          1
# ZZ119          1
# ZZ120          1
# ZZ121          1
# ZZ122          1
# ZZ123          1
# ZZ124          1
# ZZ125          1
# ZZ126          1
# ZZ741          1
# ZZ740          1
# ZZ739          1
# ZZ724          1
# ZZ712          1
# ZZ713          1
# ZZ714          1
# ZZ715          1
# ZZ716          1
# ZZ717          1
# ZZ718          1
# ZZ719          1
# ZZ720          1
# ZZ721          1
# ZZ722          1
# ZZ723          1
# ZZ725          1
# ZZ738          1
# ZZ726          1
# ZZ727          1
# ZZ728          1
# ZZ729          1
# ZZ730          1
# ZZ731          1
# ZZ732          1
# ZZ733          1
# ZZ734          1
# ZZ735          1
# ZZ736          1
# ZZ737          1
# ZZ127          1
# ZZ128          1
# ZZ129          1
# ZZ173          1
# ZZ161          1
# ZZ162          1
# ZZ163          1
# ZZ164          1
# ZZ165          1
# ZZ166          1
# ZZ167          1
# ZZ168          1
# ZZ169          1
# ZZ170          1
# ZZ171          1
# ZZ172          1
# ZZ174          1
# ZZ159          1
# ZZ175          1
# ZZ176          1
# ZZ177          1
# ZZ178          1
# ZZ179          1
# ZZ180          1
# ZZ181          1
# ZZ182          1
# ZZ183          1
# ZZ184          1
# ZZ185          1
# ZZ186          1
# ZZ160          1
# ZZ158          1
# ZZ130          1
# ZZ143          1
# ZZ131          1
# ZZ132          1
# ZZ133          1
# ZZ134          1
# ZZ135          1
# ZZ136          1
# ZZ137          1
# ZZ138          1
# ZZ139          1
# ZZ140          1
# ZZ141          1
# ZZ142          1
# ZZ144          1
# ZZ157          1
# ZZ145          1
# ZZ146          1
# ZZ147          1
# ZZ148          1
# ZZ149          1
# ZZ150          1
# ZZ151          1
# ZZ152          1
# ZZ153          1
# ZZ154          1
# ZZ155          1
# ZZ156          1
# ZZ310          1
# ZZ312          1
# UG1883         1
# ZZ506          1
# ZZ472          1
# ZZ473          1
# ZZ474          1
# ZZ475          1
# ZZ476          1
# ZZ477          1
# ZZ478          1
# ZZ479          1
# ZZ480          1
# ZZ481          1
# ZZ482          1
# ZZ483          1
# ZZ484          1
# ZZ485          1
# ZZ486          1
# ZZ487          1
# ZZ488          1
# ZZ489          1
# ZZ490          1
# ZZ491          1
# ZZ492          1
# ZZ499          1
# ZZ500          1
# ZZ501          1
# ZZ502          1
# ZZ503          1
# ZZ504          1
# ZZ471          1
# ZZ470          1
# ZZ469          1
# ZZ454          1
# ZZ436          1
# ZZ437          1
# ZZ444          1
# ZZ445          1
# ZZ446          1
# ZZ447          1
# ZZ448          1
# ZZ449          1
# ZZ450          1
# ZZ451          1
# ZZ452          1
# ZZ453          1
# ZZ455          1
# ZZ468          1
# ZZ456          1
# ZZ457          1
# ZZ458          1
# ZZ459          1
# ZZ460          1
# ZZ461          1
# ZZ462          1
# ZZ463          1
# ZZ464          1
# ZZ465          1
# ZZ466          1
# ZZ467          1
# ZZ505          1
# ZZ507          1
# ZZ313          1
# ZZ508          1
# ZZ581          1
# ZZ582          1
# ZZ583          1
# ZZ584          1
# ZZ585          1
# ZZ586          1
# ZZ587          1
# ZZ588          1
# ZZ589          1
# ZZ590          1
# ZZ591          1
# ZZ592          1
# ZZ593          1
# ZZ594          1
# ZZ595          1
# ZZ596          1
# ZZ597          1
# ZZ598          1
# ZZ599          1
# ZZ600          1
# ZZ601          1
# ZZ602          1
# ZZ603          1
# ZZ604          1
# ZZ605          1
# ZZ606          1
# ZZ607          1
# ZZ539          1
# ZZ538          1
# ZZ537          1
# ZZ521          1
# ZZ509          1
# ZZ510          1
# ZZ511          1
# ZZ512          1
# ZZ513          1
# ZZ514          1
# ZZ515          1
# ZZ516          1
# ZZ517          1
# ZZ518          1
# ZZ519          1
# ZZ520          1
# ZZ522          1
# ZZ536          1
# ZZ523          1
# ZZ524          1
# ZZ525          1
# ZZ526          1
# ZZ528          1
# ZZ529          1
# ZZ530          1
# ZZ531          1
# ZZ532          1
# ZZ533          1
# ZZ534          1
# ZZ535          1
# ZZ435          1
# ZZ434          1
# ZZ433          1
# ZZ432          1
# ZZ344          1
# ZZ345          1
# ZZ346          1
# ZZ347          1
# ZZ348          1
# ZZ349          1
# ZZ350          1
# ZZ351          1
# ZZ352          1
# ZZ353          1
# ZZ354          1
# ZZ355          1
# ZZ356          1
# ZZ357          1
# ZZ358          1
# ZZ359          1
# ZZ360          1
# ZZ361          1
# ZZ362          1
# ZZ363          1
# ZZ364          1
# ZZ365          1
# ZZ366          1
# ZZ367          1
# ZZ368          1
# ZZ369          1
# ZZ370          1
# ZZ343          1
# ZZ342          1
# ZZ341          1
# ZZ326          1
# ZZ314          1
# ZZ315          1
# ZZ316          1
# ZZ317          1
# ZZ318          1
# ZZ319          1
# ZZ320          1
# ZZ321          1
# ZZ322          1
# ZZ323          1
# ZZ324          1
# ZZ325          1
# ZZ327          1
# ZZ340          1
# ZZ328          1
# ZZ329          1
# ZZ330          1
# ZZ331          1
# ZZ332          1
# ZZ333          1
# ZZ334          1
# ZZ335          1
# ZZ336          1
# ZZ337          1
# ZZ338          1
# ZZ339          1
# ZZ371          1
# ZZ372          1
# ZZ373          1
# ZZ418          1
# ZZ405          1
# ZZ406          1
# ZZ407          1
# ZZ408          1
# ZZ409          1
# ZZ410          1
# ZZ411          1
# ZZ412          1
# ZZ413          1
# ZZ414          1
# ZZ416          1
# ZZ417          1
# ZZ419          1
# ZZ403          1
# ZZ420          1
# ZZ421          1
# ZZ422          1
# ZZ423          1
# ZZ424          1
# ZZ425          1
# ZZ426          1
# ZZ427          1
# ZZ428          1
# ZZ429          1
# ZZ430          1
# ZZ431          1
# ZZ404          1
# ZZ402          1
# ZZ374          1
# ZZ387          1
# ZZ375          1
# ZZ376          1
# ZZ377          1
# ZZ378          1
# ZZ379          1
# ZZ380          1
# ZZ381          1
# ZZ382          1
# ZZ383          1
# ZZ384          1
# ZZ385          1
# ZZ386          1
# ZZ388          1
# ZZ401          1
# ZZ389          1
# ZZ390          1
# ZZ391          1
# ZZ392          1
# ZZ393          1
# ZZ394          1
# ZZ395          1
# ZZ396          1
# ZZ397          1
# ZZ398          1
# ZZ399          1
# ZZ400          1
# ZZ711          1
# ZZ710          1
# ZZ709          1
# ZZ106-112      1
# ZZ106-84       1
# ZZ106-85       1
# ZZ106-86       1
# ZZ106-87       1
# ZZ106-88       1
# ZZ106-89       1
# ZZ106-90       1
# ZZ106-91       1
# ZZ106-92       1
# ZZ106-93       1
# ZZ106-94       1
# ZZ106-95       1
# ZZ106-96       1
# ZZ106-97       1
# ZZ106-98       1
# ZZ106-99       1
# ZZ106-100      1
# ZZ106-101      1
# ZZ106-102      1
# ZZ106-103      1
# ZZ106-104      1
# ZZ106-105      1
# ZZ106-106      1
# ZZ106-107      1
# ZZ106-108      1
# ZZ106-109      1
# ZZ106-110      1
# ZZ106-83       1
# ZZ106-82       1
# ZZ106-81       1
# ZZ106-66       1
# ZZ106-54       1
# ZZ106-55       1
# ZZ106-56       1
# ZZ106-57       1
# ZZ106-58       1
# ZZ106-59       1
# ZZ106-60       1
# ZZ106-61       1
# ZZ106-62       1
# ZZ106-63       1
# ZZ106-64       1
# ZZ106-65       1
# ZZ106-67       1
# ZZ106-80       1
# ZZ106-68       1
# ZZ106-69       1
# ZZ106-70       1
# ZZ106-71       1
# ZZ106-72       1
# ZZ106-73       1
# ZZ106-74       1
# ZZ106-75       1
# ZZ106-76       1
# ZZ106-77       1
# ZZ106-78       1
# ZZ106-79       1
# ZZ106-111      1
# ZZ106-113      1
# ZZ708          1
# ZZ106-114      1
# ZZ106-145      1
# ZZ106-146      1
# ZZ106-147      1
# ZZ106-148      1
# ZZ106-149      1
# ZZ106-150      1
# ZZ106-151      1
# ZZ106-152      1
# ZZ106-153      1
# ZZ106-154      1
# ZZ106-155      1
# ZZ106-156      1
# ZZ106-157      1
# ZZ106-158      1
# ZZ106-159      1
# ZZ106-160      1
# ZZ106-161      1
# ZZ106-162      1
# ZZ106-163      1
# ZZ106-164      1
# ZZ106-165      1
# ZZ106-166      1
# ZZ106-167      1
# ZZ106-168      1
# ZZ106-169      1
# ZZ106-170      1
# ZZ106-171      1
# ZZ106-144      1
# ZZ106-143      1
# ZZ106-142      1
# ZZ106-127      1
# ZZ106-115      1
# ZZ106-116      1
# ZZ106-117      1
# ZZ106-118      1
# ZZ106-119      1
# ZZ106-120      1
# ZZ106-121      1
# ZZ106-122      1
# ZZ106-123      1
# ZZ106-124      1
# ZZ106-125      1
# ZZ106-126      1
# ZZ106-128      1
# ZZ106-141      1
# ZZ106-129      1
# ZZ106-130      1
# ZZ106-131      1
# ZZ106-132      1
# ZZ106-133      1
# ZZ106-134      1
# ZZ106-135      1
# ZZ106-136      1
# ZZ106-137      1
# ZZ106-138      1
# ZZ106-139      1
# ZZ106-140      1
# ZZ106-53       1
# ZZ106-52       1
# ZZ106-51       1
# ZZ106-50       1
# UG2059         1
# UG2060         1
# UG2061         1
# UG2062         1
# UG2049         1
# UG2050         1
# UG2051         1
# UG1978         1
# UG1979         1
# UG1980         1
# UG1271         1
# UG1998         1
# UG1999         1
# UG2000         1
# UG2001         1
# UG2002         1
# UG2003         1
# UG2004         1
# UG2005         1
# UG2006         1
# UG2007         1
# UG2008         1
# UG2009         1
# UG2010         1
# UG2011         1
# UG2012         1
# UG2023         1
# UG2048         1
# UG2047         1
# UG2046         1
# UG1889         1
# UG1882         1
# UG1884         1
# UG1877         1
# UG1878         1
# UG1879         1
# UG1880         1
# UG1881         1
# UG1873         1
# UG1874         1
# UG1875         1
# UG1876         1
# UG1888         1
# UG1890         1
# UG2045         1
# UG1891         1
# UG1892         1
# UG1893         1
# UG1894         1
# UG1895         1
# UG1896         1
# UG1897         1
# UG2040         1
# UG2041         1
# UG2042         1
# UG2043         1
# UG2044         1
# UG2024         1
# UG2025         1
# UG2026         1
# ZZ106-36       1
# ZZ106-24       1
# ZZ106-25       1
# ZZ106-26       1
# ZZ106-27       1
# ZZ106-28       1
# ZZ106-29       1
# ZZ106-30       1
# ZZ106-31       1
# ZZ106-32       1
# ZZ106-33       1
# ZZ106-34       1
# ZZ106-35       1
# ZZ106-37       1
# ZZ106-22       1
# ZZ106-38       1
# ZZ106-39       1
# ZZ106-40       1
# ZZ106-41       1
# ZZ106-42       1
# ZZ106-43       1
# ZZ106-44       1
# ZZ106-45       1
# ZZ106-46       1
# ZZ106-47       1
# ZZ106-48       1
# ZZ106-49       1
# ZZ106-23       1
# ZZ106-21       1
# UG2027         1
# ZZ106-6        1
# UG2028         1
# UG2029         1
# UG2030         1
# UG2031         1
# UG2032         1
# UG963          1
# UG1615         1
# ZZ106-1        1
# ZZ106-2        1
# ZZ106-3        1
# ZZ106-4        1
# ZZ106-5        1
# ZZ106-7        1
# ZZ106-20       1
# ZZ106-8        1
# ZZ106-9        1
# ZZ106-10       1
# ZZ106-11       1
# ZZ106-12       1
# ZZ106-13       1
# ZZ106-14       1
# ZZ106-15       1
# ZZ106-16       1
# ZZ106-17       1
# ZZ106-18       1
# ZZ106-19       1
# ZZ106-172      1
# ZZ106-173      1
# ZZ106-174      1
# ZZ106-300      1
# ZZ106-346      1
# ZZ106-347      1
# ZZ106-348      1
# ZZ106-349      1
# ZZ106-350      1
# ZZ106-351      1
# ZZ107-1        1
# ZZ438          1
# ZZ439          1
# ZZ440          1
# ZZ441          1
# ZZ442          1
# ZZ443          1
# ZZ493          1
# ZZ494          1
# ZZ495          1
# ZZ496          1
# ZZ497          1
# ZZ498          1
# ZZ626          1
# ZZ627          1
# ZZ628          1
# ZZ629          1
# ZZ630          1
# ZZ631          1
# ZZ632          1
# ZZ633          1
# ZZ106-345      1
# ZZ106-344      1
# ZZ106-343      1
# ZZ106-324      1
# ZZ106-312      1
# ZZ106-313      1
# ZZ106-314      1
# ZZ106-315      1
# ZZ106-316      1
# ZZ106-317      1
# ZZ106-318      1
# ZZ106-319      1
# ZZ106-320      1
# ZZ106-321      1
# ZZ106-322      1
# ZZ106-323      1
# ZZ106-325      1
# ZZ106-342      1
# ZZ106-326      1
# ZZ106-327      1
# ZZ106-328      1
# ZZ106-329      1
# ZZ106-330      1
# ZZ106-331      1
# ZZ106-332      1
# ZZ106-333      1
# ZZ106-338      1
# ZZ106-339      1
# ZZ106-340      1
# ZZ106-341      1
# ZZ634          1
# ZZ635          1
# ZZ636          1
# ZZ694          1
# ZZ682          1
# ZZ683          1
# ZZ684          1
# ZZ685          1
# ZZ686          1
# ZZ687          1
# ZZ688          1
# ZZ689          1
# ZZ690          1
# ZZ691          1
# ZZ692          1
# ZZ693          1
# ZZ695          1
# ZZ680          1
# ZZ696          1
# ZZ697          1
# ZZ698          1
# ZZ699          1
# ZZ700          1
# ZZ701          1
# ZZ702          1
# ZZ703          1
# ZZ704          1
# ZZ705          1
# ZZ706          1
# ZZ707          1
# ZZ681          1
# ZZ679          1
# ZZ637          1
# ZZ664          1
# ZZ638          1
# ZZ639          1
# ZZ640          1
# ZZ641          1
# ZZ642          1
# ZZ657          1
# ZZ658          1
# ZZ659          1
# ZZ660          1
# ZZ661          1
# ZZ662          1
# ZZ663          1
# ZZ665          1
# ZZ678          1
# ZZ666          1
# ZZ667          1
# ZZ668          1
# ZZ669          1
# ZZ670          1
# ZZ671          1
# ZZ672          1
# ZZ673          1
# ZZ674          1
# ZZ675          1
# ZZ676          1
# ZZ677          1
# ZZ106-301      1
# ZZ106-299      1
# ZZ106-175      1
# ZZ106-298      1
# ZZ106-206      1
# ZZ106-207      1
# ZZ106-208      1
# ZZ106-209      1
# ZZ106-210      1
# ZZ106-211      1
# ZZ106-212      1
# ZZ106-213      1
# ZZ106-214      1
# ZZ106-215      1
# ZZ106-216      1
# ZZ106-217      1
# ZZ106-218      1
# ZZ106-219      1
# ZZ106-220      1
# ZZ106-221      1
# ZZ106-222      1
# ZZ106-223      1
# ZZ106-224      1
# ZZ106-225      1
# ZZ106-226      1
# ZZ106-227      1
# ZZ106-228      1
# ZZ106-229      1
# ZZ106-230      1
# ZZ106-231      1
# ZZ106-232      1
# ZZ106-205      1
# ZZ106-204      1
# ZZ106-203      1
# ZZ106-188      1
# ZZ106-176      1
# ZZ106-177      1
# ZZ106-178      1
# ZZ106-179      1
# ZZ106-180      1
# ZZ106-181      1
# ZZ106-182      1
# ZZ106-183      1
# ZZ106-184      1
# ZZ106-185      1
# ZZ106-186      1
# ZZ106-187      1
# ZZ106-189      1
# ZZ106-202      1
# ZZ106-190      1
# ZZ106-191      1
# ZZ106-192      1
# ZZ106-193      1
# ZZ106-194      1
# ZZ106-195      1
# ZZ106-196      1
# ZZ106-197      1
# ZZ106-198      1
# ZZ106-199      1
# ZZ106-200      1
# ZZ106-201      1
# ZZ106-233      1
# ZZ106-234      1
# ZZ106-235      1
# ZZ106-284      1
# ZZ106-267      1
# ZZ106-268      1
# ZZ106-269      1
# ZZ106-270      1
# ZZ106-272      1
# ZZ106-273      1
# ZZ106-274      1
# ZZ106-275      1
# ZZ106-277      1
# ZZ106-278      1
# ZZ106-279      1
# ZZ106-283      1
# ZZ106-285      1
# ZZ106-265      1
# ZZ106-286      1
# ZZ106-287      1
# ZZ106-288      1
# ZZ106-289      1
# ZZ106-290      1
# ZZ106-291      1
# ZZ106-292      1
# ZZ106-293      1
# ZZ106-294      1
# ZZ106-295      1
# ZZ106-296      1
# ZZ106-297      1
# ZZ106-266      1
# ZZ106-264      1
# ZZ106-236      1
# ZZ106-249      1
# ZZ106-237      1
# ZZ106-238      1
# ZZ106-239      1
# ZZ106-240      1
# ZZ106-241      1
# ZZ106-242      1
# ZZ106-243      1
# ZZ106-244      1
# ZZ106-245      1
# ZZ106-246      1
# ZZ106-247      1
# ZZ106-248      1
# ZZ106-250      1
# ZZ106-263      1
# ZZ106-251      1
# ZZ106-252      1
# ZZ106-253      1
# ZZ106-254      1
# ZZ106-255      1
# ZZ106-256      1
# ZZ106-257      1
# ZZ106-258      1
# ZZ106-259      1
# ZZ106-260      1
# ZZ106-261      1
# ZZ106-262      1
# TN947          1
# TN945          1
# GH2            1
# GH667          1
# GH639          1
# GH640          1
# GH641          1
# GH642          1
# GH643          1
# GH644          1
# GH645          1
# GH646          1
# GH647          1
# GH648          1
# GH649          1
# GH650          1
# GH651          1
# GH652          1
# GH653          1
# GH654          1
# GH655          1
# GH656          1
# GH657          1
# GH658          1
# GH659          1
# GH660          1
# GH661          1
# GH662          1
# GH663          1
# GH664          1
# GH665          1
# GH638          1
# GH637          1
# GH636          1
# GH621          1
# GH609          1
# GH610          1
# GH611          1
# GH612          1
# GH613          1
# GH614          1
# GH615          1
# GH616          1
# GH617          1
# GH618          1
# GH619          1
# GH620          1
# GH622          1
# GH635          1
# GH623          1
# GH624          1
# GH625          1
# GH626          1
# GH627          1
# GH628          1
# GH629          1
# GH630          1
# GH631          1
# GH632          1
# GH633          1
# GH634          1
# GH666          1
# GH668          1
# GH728          1
# GH669          1
# GH700          1
# GH701          1
# GH702          1
# GH703          1
# GH704          1
# GH705          1
# GH706          1
# GH707          1
# GH708          1
# GH709          1
# GH710          1
# GH711          1
# GH712          1
# GH713          1
# GH714          1
# GH715          1
# GH716          1
# GH717          1
# GH718          1
# GH719          1
# GH720          1
# GH721          1
# GH722          1
# GH723          1
# GH724          1
# GH725          1
# GH726          1
# GH699          1
# GH698          1
# GH697          1
# GH682          1
# GH670          1
# GH671          1
# GH672          1
# GH673          1
# GH674          1
# GH675          1
# GH676          1
# GH677          1
# GH678          1
# GH679          1
# GH680          1
# GH681          1
# GH683          1
# GH696          1
# GH684          1
# GH685          1
# GH686          1
# GH687          1
# GH688          1
# GH689          1
# GH690          1
# GH691          1
# GH692          1
# GH693          1
# GH694          1
# GH695          1
# GH608          1
# GH607          1
# GH606          1
# GH605          1
# GH518          1
# GH519          1
# GH520          1
# GH521          1
# GH522          1
# GH523          1
# GH524          1
# GH525          1
# GH526          1
# GH527          1
# GH528          1
# GH529          1
# GH530          1
# GH531          1
# GH532          1
# GH533          1
# GH534          1
# GH535          1
# GH536          1
# GH537          1
# GH538          1
# GH539          1
# GH540          1
# GH541          1
# GH542          1
# GH543          1
# GH544          1
# GH517          1
# GH516          1
# GH515          1
# GH500          1
# GH488          1
# GH489          1
# GH490          1
# GH491          1
# GH492          1
# GH493          1
# GH494          1
# GH495          1
# GH496          1
# GH497          1
# GH498          1
# GH499          1
# GH501          1
# GH514          1
# GH502          1
# GH503          1
# GH504          1
# GH505          1
# GH506          1
# GH507          1
# GH508          1
# GH509          1
# GH510          1
# GH511          1
# GH512          1
# GH513          1
# GH545          1
# GH546          1
# GH547          1
# GH591          1
# GH579          1
# GH580          1
# GH581          1
# GH582          1
# GH583          1
# GH584          1
# GH585          1
# GH586          1
# GH587          1
# GH588          1
# GH589          1
# GH590          1
# GH592          1
# GH577          1
# GH593          1
# GH594          1
# GH595          1
# GH596          1
# GH597          1
# GH598          1
# GH599          1
# GH600          1
# GH601          1
# GH602          1
# GH603          1
# GH604          1
# GH578          1
# GH576          1
# GH548          1
# GH561          1
# GH549          1
# GH550          1
# GH551          1
# GH552          1
# GH553          1
# GH554          1
# GH555          1
# GH556          1
# GH557          1
# GH558          1
# GH559          1
# GH560          1
# GH562          1
# GH575          1
# GH563          1
# GH564          1
# GH565          1
# GH566          1
# GH567          1
# GH568          1
# GH569          1
# GH570          1
# GH571          1
# GH572          1
# GH573          1
# GH574          1
# GH727          1
# GH729          1
# TN944          1
# GH910          1
# GH882          1
# GH883          1
# GH884          1
# GH885          1
# GH886          1
# GH887          1
# GH888          1
# GH889          1
# GH890          1
# GH891          1
# GH892          1
# GH893          1
# GH894          1
# GH895          1
# GH896          1
# GH897          1
# GH898          1
# GH899          1
# GH900          1
# GH901          1
# GH902          1
# GH903          1
# GH904          1
# GH905          1
# GH906          1
# GH907          1
# GH908          1
# GH881          1
# GH880          1
# GH879          1
# GH864          1
# GH852          1
# GH853          1
# GH854          1
# GH855          1
# GH856          1
# GH857          1
# GH858          1
# GH859          1
# GH860          1
# GH861          1
# GH862          1
# GH863          1
# GH865          1
# GH878          1
# GH866          1
# GH867          1
# GH868          1
# GH869          1
# GH870          1
# GH871          1
# GH872          1
# GH873          1
# GH874          1
# GH875          1
# GH876          1
# GH877          1
# GH909          1
# GH911          1
# GH730          1
# GH912          1
# GH943          1
# GH944          1
# GH945          1
# GH946          1
# GH947          1
# GH948          1
# GH949          1
# GH950          1
# GH951          1
# GH952          1
# GH953          1
# GH954          1
# GH955          1
# GH956          1
# GH957          1
# GH958          1
# GH960          1
# GH961          1
# GH962          1
# GH963          1
# GH964          1
# GH965          1
# GH966          1
# GH967          1
# GH968          1
# GH969          1
# GH970          1
# GH942          1
# GH941          1
# GH940          1
# GH925          1
# GH913          1
# GH914          1
# GH915          1
# GH916          1
# GH917          1
# GH918          1
# GH919          1
# GH920          1
# GH921          1
# GH922          1
# GH923          1
# GH924          1
# GH926          1
# GH939          1
# GH927          1
# GH928          1
# GH929          1
# GH930          1
# GH931          1
# GH932          1
# GH933          1
# GH934          1
# GH935          1
# GH936          1
# GH937          1
# GH938          1
# GH851          1
# GH850          1
# GH849          1
# GH848          1
# GH761          1
# GH762          1
# GH763          1
# GH764          1
# GH765          1
# GH766          1
# GH767          1
# GH768          1
# GH769          1
# GH770          1
# GH771          1
# GH772          1
# GH773          1
# GH774          1
# GH775          1
# GH776          1
# GH777          1
# GH778          1
# GH779          1
# GH780          1
# GH781          1
# GH782          1
# GH783          1
# GH784          1
# GH785          1
# GH786          1
# GH787          1
# GH760          1
# GH759          1
# GH758          1
# GH743          1
# GH731          1
# GH732          1
# GH733          1
# GH734          1
# GH735          1
# GH736          1
# GH737          1
# GH738          1
# GH739          1
# GH740          1
# GH741          1
# GH742          1
# GH744          1
# GH757          1
# GH745          1
# GH746          1
# GH747          1
# GH748          1
# GH749          1
# GH750          1
# GH751          1
# GH752          1
# GH753          1
# GH754          1
# GH755          1
# GH756          1
# GH788          1
# GH789          1
# GH790          1
# GH834          1
# GH822          1
# GH823          1
# GH824          1
# GH825          1
# GH826          1
# GH827          1
# GH828          1
# GH829          1
# GH830          1
# GH831          1
# GH832          1
# GH833          1
# GH835          1
# GH820          1
# GH836          1
# GH837          1
# GH838          1
# GH839          1
# GH840          1
# GH841          1
# GH842          1
# GH843          1
# GH844          1
# GH845          1
# GH846          1
# GH847          1
# GH821          1
# GH819          1
# GH791          1
# GH804          1
# GH792          1
# GH793          1
# GH794          1
# GH795          1
# GH796          1
# GH797          1
# GH798          1
# GH799          1
# GH800          1
# GH801          1
# GH802          1
# GH803          1
# GH805          1
# GH818          1
# GH806          1
# GH807          1
# GH808          1
# GH809          1
# GH810          1
# GH811          1
# GH812          1
# GH813          1
# GH814          1
# GH815          1
# GH816          1
# GH817          1
# GH487          1
# GH486          1
# GH485          1
# GH182          1
# GH154          1
# GH155          1
# GH156          1
# GH157          1
# GH158          1
# GH159          1
# GH160          1
# GH161          1
# GH162          1
# GH163          1
# GH164          1
# GH165          1
# GH166          1
# GH167          1
# GH168          1
# GH169          1
# GH170          1
# GH171          1
# GH172          1
# GH173          1
# GH174          1
# GH175          1
# GH176          1
# GH177          1
# GH178          1
# GH179          1
# GH180          1
# GH153          1
# GH152          1
# GH151          1
# GH136          1
# GH124          1
# GH125          1
# GH126          1
# GH127          1
# GH128          1
# GH129          1
# GH130          1
# GH131          1
# GH132          1
# GH133          1
# GH134          1
# GH135          1
# GH137          1
# GH150          1
# GH138          1
# GH139          1
# GH140          1
# GH141          1
# GH142          1
# GH143          1
# GH144          1
# GH145          1
# GH146          1
# GH147          1
# GH148          1
# GH149          1
# GH181          1
# GH183          1
# GH484          1
# GH184          1
# GH215          1
# GH216          1
# GH217          1
# GH218          1
# GH219          1
# GH220          1
# GH221          1
# GH222          1
# GH223          1
# GH224          1
# GH225          1
# GH226          1
# GH227          1
# GH228          1
# GH229          1
# GH230          1
# GH231          1
# GH232          1
# GH233          1
# GH234          1
# GH235          1
# GH236          1
# GH237          1
# GH238          1
# GH239          1
# GH240          1
# GH241          1
# GH214          1
# GH213          1
# GH212          1
# GH197          1
# GH185          1
# GH186          1
# GH187          1
# GH188          1
# GH189          1
# GH190          1
# GH191          1
# GH192          1
# GH193          1
# GH194          1
# GH195          1
# GH196          1
# GH198          1
# GH211          1
# GH199          1
# GH200          1
# GH201          1
# GH202          1
# GH203          1
# GH204          1
# GH205          1
# GH206          1
# GH207          1
# GH208          1
# GH209          1
# GH210          1
# GH123          1
# GH122          1
# GH121          1
# GH120          1
# GH33           1
# GH34           1
# GH35           1
# GH36           1
# GH37           1
# GH38           1
# GH39           1
# GH40           1
# GH41           1
# GH42           1
# GH43           1
# GH44           1
# GH45           1
# GH46           1
# GH47           1
# GH48           1
# GH49           1
# GH50           1
# GH51           1
# GH52           1
# GH53           1
# GH54           1
# GH55           1
# GH56           1
# GH57           1
# GH58           1
# GH59           1
# GH32           1
# GH31           1
# GH30           1
# GH15           1
# GH3            1
# GH4            1
# GH5            1
# GH6            1
# GH7            1
# GH8            1
# GH9            1
# GH10           1
# GH11           1
# GH12           1
# GH13           1
# GH14           1
# GH16           1
# GH29           1
# GH17           1
# GH18           1
# GH19           1
# GH20           1
# GH21           1
# GH22           1
# GH23           1
# GH24           1
# GH25           1
# GH26           1
# GH27           1
# GH28           1
# GH60           1
# GH61           1
# GH62           1
# GH106          1
# GH94           1
# GH95           1
# GH96           1
# GH97           1
# GH98           1
# GH99           1
# GH100          1
# GH101          1
# GH102          1
# GH103          1
# GH104          1
# GH105          1
# GH107          1
# GH92           1
# GH108          1
# GH109          1
# GH110          1
# GH111          1
# GH112          1
# GH113          1
# GH114          1
# GH115          1
# GH116          1
# GH117          1
# GH118          1
# GH119          1
# GH93           1
# GH91           1
# GH63           1
# GH76           1
# GH64           1
# GH65           1
# GH66           1
# GH67           1
# GH68           1
# GH69           1
# GH70           1
# GH71           1
# GH72           1
# GH73           1
# GH74           1
# GH75           1
# GH77           1
# GH90           1
# GH78           1
# GH79           1
# GH80           1
# GH81           1
# GH82           1
# GH83           1
# GH84           1
# GH85           1
# GH86           1
# GH87           1
# GH88           1
# GH89           1
# GH242          1
# GH243          1
# GH244          1
# GH365          1
# GH397          1
# GH398          1
# GH399          1
# GH400          1
# GH401          1
# GH402          1
# GH403          1
# GH404          1
# GH405          1
# GH406          1
# GH407          1
# GH408          1
# GH409          1
# GH410          1
# GH411          1
# GH412          1
# GH413          1
# GH414          1
# GH415          1
# GH416          1
# GH417          1
# GH418          1
# GH419          1
# GH420          1
# GH421          1
# GH422          1
# GH423          1
# GH396          1
# GH395          1
# GH394          1
# GH379          1
# GH367          1
# GH368          1
# GH369          1
# GH370          1
# GH371          1
# GH372          1
# GH373          1
# GH374          1
# GH375          1
# GH376          1
# GH377          1
# GH378          1
# GH380          1
# GH393          1
# GH381          1
# GH382          1
# GH383          1
# GH384          1
# GH385          1
# GH386          1
# GH387          1
# GH388          1
# GH389          1
# GH390          1
# GH391          1
# GH392          1
# GH424          1
# GH425          1
# GH426          1
# GH470          1
# GH458          1
# GH459          1
# GH460          1
# GH461          1
# GH462          1
# GH463          1
# GH464          1
# GH465          1
# GH466          1
# GH467          1
# GH468          1
# GH469          1
# GH471          1
# GH456          1
# GH472          1
# GH473          1
# GH474          1
# GH475          1
# GH476          1
# GH477          1
# GH478          1
# GH479          1
# GH480          1
# GH481          1
# GH482          1
# GH483          1
# GH457          1
# GH455          1
# GH427          1
# GH440          1
# GH428          1
# GH429          1
# GH430          1
# GH431          1
# GH432          1
# GH433          1
# GH434          1
# GH435          1
# GH436          1
# GH437          1
# GH438          1
# GH439          1
# GH441          1
# GH454          1
# GH442          1
# GH443          1
# GH444          1
# GH445          1
# GH446          1
# GH447          1
# GH448          1
# GH449          1
# GH450          1
# GH451          1
# GH452          1
# GH453          1
# GH366          1
# GH364          1
# GH245          1
# GH363          1
# GH276          1
# GH277          1
# GH278          1
# GH279          1
# GH280          1
# GH281          1
# GH282          1
# GH283          1
# GH284          1
# GH285          1
# GH286          1
# GH287          1
# GH288          1
# GH289          1
# GH290          1
# GH291          1
# GH292          1
# GH293          1
# GH294          1
# GH295          1
# GH296          1
# GH297          1
# GH298          1
# GH299          1
# GH300          1
# GH301          1
# ...
# 08/01/1985                                                                                                                                                                                                                                                           1
# 14/05/2000                                                                                                                                                                                                                                                           1
# 22/10/2000                                                                                                                                                                                                                                                           1
# 15/08/1996                                                                                                                                                                                                                                                           1
# 09/10/2002                                                                                                                                                                                                                                                           1
# 04/09/2001                                                                                                                                                                                                                                                           1
# 28/04/1998                                                                                                                                                                                                                                                           1
# 18/02/1987                                                                                                                                                                                                                                                           1
# 07/04/1995                                                                                                                                                                                                                                                           1
# 15/04/1988                                                                                                                                                                                                                                                           1
# 14/02/1989                                                                                                                                                                                                                                                           1
# 25/12/1997                                                                                                                                                                                                                                                           1
# 02/06/1991                                                                                                                                                                                                                                                           1
# 01/05/1995                                                                                                                                                                                                                                                           1
# 28/11/1991                                                                                                                                                                                                                                                           1
# 21/09/2003                                                                                                                                                                                                                                                           1
# 23/02/1995                                                                                                                                                                                                                                                           1
# 23/06/1989                                                                                                                                                                                                                                                           1
# 12/09/1983                                                                                                                                                                                                                                                           1
# 17/03/1986                                                                                                                                                                                                                                                           1
# 21/05/2000                                                                                                                                                                                                                                                           1
# 15/07/1997                                                                                                                                                                                                                                                           1
# 09/11/1992                                                                                                                                                                                                                                                           1
# 14/03/1997                                                                                                                                                                                                                                                           1
# 04/10/1983                                                                                                                                                                                                                                                           1
# 11/04/1986                                                                                                                                                                                                                                                           1
# 21/09/1994                                                                                                                                                                                                                                                           1
# 06/06/2001                                                                                                                                                                                                                                                           1
# 06/04/1985                                                                                                                                                                                                                                                           1
# 11/04/1990                                                                                                                                                                                                                                                           1
# 25/01/1993                                                                                                                                                                                                                                                           1
# 08/06/1994                                                                                                                                                                                                                                                           1
# 28/04/1994                                                                                                                                                                                                                                                           1
# 08/08/1988                                                                                                                                                                                                                                                           1
# 24/04/1987                                                                                                                                                                                                                                                           1
# 27/10/2002                                                                                                                                                                                                                                                           1
# 29/10/1995                                                                                                                                                                                                                                                           1
# 12/24/2004                                                                                                                                                                                                                                                           1
# Name: count, dtype: int64
# ----------------------------------------
# Column: sex_guardian
# sex_guardian
# 1         1988
# Female    1376
# Male       503
# NaN        101
# 0           15
# Name: count, dtype: int64
# ----------------------------------------
# Column: guardian_relationship
# guardian_relationship
# 2.0            1979
# Mother         1836
# NaN             106
# Father           29
# 1.0              12
# Grandparent      11
# 3.0               5
# 5.0               2
# Aunt              2
# Sister            1
# Name: count, dtype: int64
# ----------------------------------------
# Column: detection_at_birth
# detection_at_birth
# 4.0                      1114
# Agree                     828
# Strongly Agree            735
# 3.0                       453
# Neutral/ I don't know     285
# 2.0                       232
# 5.0                       164
# NaN                       117
# 1.0                        27
# Disagree                   22
# Strongly Disagree           6
# Name: count, dtype: int64
# ----------------------------------------
# Column: scd_longevity
# scd_longevity
# Agree                    1161
# 4.0                       889
# 3.0                       503
# 2.0                       426
# Strongly Agree            422
# Neutral/ I don't know     175
# 5.0                       133
# NaN                       118
# Disagree                  102
# 1.0                        37
# Strongly Disagree          17
# Name: count, dtype: int64
# ----------------------------------------
# Column: early_detection_importance
# early_detection_importance
# 4.0                      1337
# Agree                    1091
# Strongly Agree            637
# 5.0                       376
# 3.0                       243
# Neutral/ I don't know     132
# NaN                       120
# 2.0                        31
# Disagree                   13
# 1.0                         3
# Name: count, dtype: int64
# ----------------------------------------
# Column: need_immediate_result
# need_immediate_result
# 4.0                      1361
# Agree                    1194
# Strongly Agree            541
# 5.0                       393
# 3.0                       208
# Neutral/ I don't know     126
# NaN                       122
# 2.0                        23
# Disagree                   13
# 1.0                         2
# Name: count, dtype: int64
# ----------------------------------------
# Column: enough_poct_info
# enough_poct_info
# 4.0                      1373
# Agree                    1006
# 5.0                       465
# Strongly Agree            403
# Neutral/ I don't know     276
# Disagree                  160
# 3.0                       129
# NaN                       125
# Strongly Disagree          32
# 2.0                        11
# 1.0                         3
# Name: count, dtype: int64
# ----------------------------------------
# Column: poct_result_speed
# poct_result_speed
# 4.0                      1208
# Agree                    1172
# 5.0                       445
# Strongly Agree            416
# 3.0                       311
# Neutral/ I don't know     275
# NaN                       122
# 2.0                        18
# Disagree                   11
# 1.0                         5
# Name: count, dtype: int64
# ----------------------------------------
# Column: screening_recommendation
# screening_recommendation
# 4.0                      1341
# Agree                    1163
# Strongly Agree            619
# 5.0                       514
# NaN                       128
# 3.0                       119
# Neutral/ I don't know      83
# Disagree                    8
# 2.0                         7
# 1.0                         1
# Name: count, dtype: int64
# ----------------------------------------
# Column: poct_recommendation
# poct_recommendation
# 4.0                      1345
# Agree                    1235
# Strongly Agree            539
# 5.0                       505
# 3.0                       129
# NaN                       126
# Neutral/ I don't know      96
# Disagree                    4
# 2.0                         3
# 1.0                         1
# Name: count, dtype: int64
# ----------------------------------------
# Column: dbs_for_validation
# dbs_for_validation
# 4.0                      1333
# Agree                    1171
# 5.0                       457
# Neutral/ I don't know     355
# Strongly Agree            336
# 3.0                       190
# NaN                       125
# Disagree                   11
# 2                           4
# 1.0                         1
# Name: count, dtype: int64
# ----------------------------------------
# Column: proper_treatment
# proper_treatment
# 4.0                      1277
# Agree                    1220
# 5.0                       619
# Strongly Agree            567
# NaN                       128
# 3.0                        85
# Neutral/ I don't know      76
# Disagree                    6
# 1.0                         2
# 2                           2
# Strongly Disagree           1
# Name: count, dtype: int64
# ----------------------------------------
# Column: scd_in_the_family
# scd_in_the_family
# 2.0             1620
# No              1077
# I don't know     649
# 3.0              194
# 1.0              163
# Yes              150
# NaN              130
# Name: count, dtype: int64
# ----------------------------------------
# Column: registry_willingness
# registry_willingness
# 1.0    1952
# Yes    1866
# NaN     142
# 0.0      12
# No       11
# Name: count, dtype: int64
# ----------------------------------------
# Column: no_followup_reasons
# no_followup_reasons
# 1.0    1972
# Yes    1879
# NaN     121
# 2.0      11
# Name: count, dtype: int64
# ----------------------------------------
# Column: nofollowup_reason_specified
# nofollowup_reason_specified
# NaN                 3981
# LIVING IN TANGA        1
# 4.0                    1
# Name: count, dtype: int64
# ----------------------------------------
# Column: country
# country
# Zimbabwe/Zambia    1000
# Ghana               999
# Uganda              980
# Tanzania            900
# Mali                104
# Name: count, dtype: int64
# ----------------------------------------

# %%
df_questionnaire.columns
# Out:
# Index(['record_id', 'participant_id', 'facility_id', 'screening_date',
#        'dob_guardian', 'sex_guardian', 'guardian_relationship',
#        'detection_at_birth', 'scd_longevity', 'early_detection_importance',
#        'need_immediate_result', 'enough_poct_info', 'poct_result_speed',
#        'screening_recommendation', 'poct_recommendation', 'dbs_for_validation',
#        'proper_treatment', 'scd_in_the_family', 'registry_willingness',
#        'no_followup_reasons', 'nofollowup_reason_specified', 'country'],
#       dtype='object')

# %%
# Define the general mapping dictionary
value_map_general = {
    'Strongly Disagree': 1.0,
    'Disagree': 2.0,
    'Neutral/ I don\'t know': 3.0,
    'I don\'t know': 3.0,
    'Agree': 4.0,
    'Strongly Agree': 5.0,
    'Yes': 1.0,
    'No': 0.0,
    'Oui': 1.0  # If applicable for 'Oui'
}

# Columns to map
columns_to_map = [
    'detection_at_birth', 'scd_longevity', 'early_detection_importance',
    'need_immediate_result', 'enough_poct_info', 'poct_result_speed',
    'screening_recommendation', 'poct_recommendation', 'dbs_for_validation',
    'proper_treatment', 'scd_in_the_family', 'registry_willingness',
    'no_followup_reasons'
]

# Apply the mapping to all specified columns
for col in columns_to_map:
    df_questionnaire[col] = df_questionnaire[col].replace(value_map_general)

# %%
df_questionnaire.head()
# Out:
#   record_id participant_id facility_id screening_date dob_guardian  \
# 0       GH1          ML001       GH001     20 02 2024   12 10 1996
# 1       GH2          ML002       GH001     20 02 2024          NaN
# 2       GH3          ML003       GH001     20 02 2024   28 09 1991
# 3       GH4          ML004       GH001     20 02 2024          NaN
# 4       GH5          ML005       GH001     21 02 2024    1 01 1993
#
#   sex_guardian guardian_relationship  detection_at_birth  scd_longevity  \
# 0            1                   2.0                 3.0            2.0
# 1            1                   2.0                 5.0            2.0
# 2            1                   2.0                 3.0            2.0
# 3            1                   2.0                 5.0            4.0
# 4            1                   2.0                 4.0            3.0
#
#    early_detection_importance  need_immediate_result  enough_poct_info  \
# 0                         4.0                    5.0               5.0
# 1                         4.0                    5.0               5.0
# 2                         4.0                    5.0               5.0
# 3                         5.0                    2.0               5.0
# 4                         3.0                    3.0               4.0
#
#    poct_result_speed  screening_recommendation  poct_recommendation  \
# 0                4.0                       5.0                  5.0
# 1                3.0                       5.0                  5.0
# 2                5.0                       5.0                  5.0
# 3                4.0                       5.0                  5.0
# 4                4.0                       4.0                  4.0
#
#    dbs_for_validation  proper_treatment  scd_in_the_family  \
# 0                 4.0               5.0                2.0
# 1                 5.0               5.0                3.0
# 2                 4.0               5.0                2.0
# 3                 5.0               5.0                2.0
# 4                 4.0               4.0                2.0
#
#    registry_willingness  no_followup_reasons nofollowup_reason_specified  \
# 0                   1.0                  1.0                         NaN
# 1                   1.0                  1.0                         NaN
# 2                   1.0                  1.0                         NaN
# 3                   1.0                  1.0                         NaN
# 4                   1.0                  1.0                         NaN
#
#   country
# 0   Ghana
# 1   Ghana
# 2   Ghana
# 3   Ghana
# 4   Ghana

# %%
value_map_general = {
    'Strongly Disagree': 1.0,
    'Disagree': 2.0,
    'Neutral/ I don\'t know': 3.0,
    'I don\'t know': 3.0,
    'Agree': 4.0,
    'Strongly Agree': 5.0,
    'Yes': 1.0,
    'No': 0.0,
    'Oui': 1.0  
}

value_map_guardian = {
    'Father': 1.0,
    'Mother': 2.0,
    'Aunt': 3.0,
    'Uncle': 4.0,
    'Grandparent': 5.0,
    'Sister': 6.0,
    'Brother': 7.0,
    'Cousin': 8.0,
    'Other': 9.0 
}

# Columns to map
columns_to_map = [
    'detection_at_birth', 'scd_longevity', 'early_detection_importance',
    'need_immediate_result', 'enough_poct_info', 'poct_result_speed',
    'screening_recommendation', 'poct_recommendation', 'dbs_for_validation',
    'proper_treatment', 'scd_in_the_family', 'registry_willingness',
    'no_followup_reasons'
]

# Apply the mapping to all specified columns
for col in columns_to_map:
    df_questionnaire[col] = df_questionnaire[col].replace(value_map_general)
    df_questionnaire[col] = pd.to_numeric(df_questionnaire[col], errors='coerce').astype('Int64')
    
df_questionnaire['guardian_relationship'] = df_questionnaire['guardian_relationship'].replace(value_map_guardian)
df_questionnaire['guardian_relationship'] = pd.to_numeric(df_questionnaire['guardian_relationship'], \
                                                          errors='coerce').astype('Int64')

# %%
df_questionnaire.columns
# Out:
# Index(['record_id', 'participant_id', 'facility_id', 'screening_date',
#        'dob_guardian', 'sex_guardian', 'guardian_relationship',
#        'detection_at_birth', 'scd_longevity', 'early_detection_importance',
#        'need_immediate_result', 'enough_poct_info', 'poct_result_speed',
#        'screening_recommendation', 'poct_recommendation', 'dbs_for_validation',
#        'proper_treatment', 'scd_in_the_family', 'registry_willingness',
#        'no_followup_reasons', 'nofollowup_reason_specified', 'country'],
#       dtype='object')

# %%
# 1) Columns that are entirely missing (global)
all_missing_cols = df_questionnaire.columns[df_questionnaire.isna().all()].tolist()
print(f"All-missing columns ({len(all_missing_cols)}):\n", all_missing_cols)

df_questionnaire_clean = df_questionnaire.drop(columns=all_missing_cols)

THRESH = 0.95
missing_frac = df_questionnaire.isna().mean().sort_values(ascending=False)
near_all_missing = missing_frac[missing_frac >= THRESH].index.tolist()
print(f"\nNear-all-missing (≥{int(THRESH*100)}% missing) ({len(near_all_missing)}):\n", near_all_missing)

missing_summary = pd.DataFrame({
    'n_missing': df_questionnaire.isna().sum(),
    'pct_missing': df_questionnaire.isna().mean()
}).sort_values('pct_missing', ascending=False)
print("\nMissingness summary (top 20):")
print(missing_summary.head(20))
# Out:
# All-missing columns (0):
#  []
#
# Near-all-missing (≥95% missing) (1):
#  ['nofollowup_reason_specified']
#
# Missingness summary (top 20):
#                              n_missing  pct_missing
# nofollowup_reason_specified       3981     0.999498
# dob_guardian                       756     0.189807
# registry_willingness               142     0.035652
# scd_in_the_family                  130     0.032639
# proper_treatment                   128     0.032137
# screening_recommendation           128     0.032137
# poct_recommendation                126     0.031634
# enough_poct_info                   125     0.031383
# dbs_for_validation                 125     0.031383
# poct_result_speed                  122     0.030630
# need_immediate_result              122     0.030630
# no_followup_reasons                121     0.030379
# early_detection_importance         120     0.030128
# scd_longevity                      118     0.029626
# detection_at_birth                 117     0.029375
# screening_date                     107     0.026864
# guardian_relationship              106     0.026613
# participant_id                     102     0.025609
# facility_id                        102     0.025609
# sex_guardian                       101     0.025358

# %%
df_questionnaire.head()
# Out:
#   record_id participant_id facility_id screening_date dob_guardian  \
# 0       GH1          ML001       GH001     20 02 2024   12 10 1996
# 1       GH2          ML002       GH001     20 02 2024          NaN
# 2       GH3          ML003       GH001     20 02 2024   28 09 1991
# 3       GH4          ML004       GH001     20 02 2024          NaN
# 4       GH5          ML005       GH001     21 02 2024    1 01 1993
#
#   sex_guardian  guardian_relationship  detection_at_birth  scd_longevity  \
# 0            1                      2                   3              2
# 1            1                      2                   5              2
# 2            1                      2                   3              2
# 3            1                      2                   5              4
# 4            1                      2                   4              3
#
#    early_detection_importance  need_immediate_result  enough_poct_info  \
# 0                           4                      5                 5
# 1                           4                      5                 5
# 2                           4                      5                 5
# 3                           5                      2                 5
# 4                           3                      3                 4
#
#    poct_result_speed  screening_recommendation  poct_recommendation  \
# 0                  4                         5                    5
# 1                  3                         5                    5
# 2                  5                         5                    5
# 3                  4                         5                    5
# 4                  4                         4                    4
#
#    dbs_for_validation  proper_treatment  scd_in_the_family  \
# 0                   4                 5                  2
# 1                   5                 5                  3
# 2                   4                 5                  2
# 3                   5                 5                  2
# 4                   4                 4                  2
#
#    registry_willingness  no_followup_reasons nofollowup_reason_specified  \
# 0                     1                    1                         NaN
# 1                     1                    1                         NaN
# 2                     1                    1                         NaN
# 3                     1                    1                         NaN
# 4                     1                    1                         NaN
#
#   country
# 0   Ghana
# 1   Ghana
# 2   Ghana
# 3   Ghana
# 4   Ghana

# %%
df_questionnaire['nofollowup_reason_specified'].value_counts()
# Out:
# nofollowup_reason_specified
# LIVING IN TANGA     1
# 4.0                 1
# Name: count, dtype: int64

# %%
# Guardian questions
columns_to_map
# Out:
# ['detection_at_birth',
#  'scd_longevity',
#  'early_detection_importance',
#  'need_immediate_result',
#  'enough_poct_info',
#  'poct_result_speed',
#  'screening_recommendation',
#  'poct_recommendation',
#  'dbs_for_validation',
#  'proper_treatment',
#  'scd_in_the_family',
#  'registry_willingness',
#  'no_followup_reasons']

# %%
sex_guardian_scales = {0: 'Male', 1: 'Female'}

guardian_relationship_scales = {
    1: 'Father', 2: 'Mother', 3: 'Aunt', 4: 'Uncle', 5: 'Grandparent',
    6: 'Sister', 7: 'Brother', 8: 'SCousin', 9: 'Other'
}

scd_in_the_family_scales = {1: 'Yes', 2: 'No', 3: "I don't know"}
registry_willingness_scales = {1: 'Yes', 2: 'No'}
no_followup_reasons_scales = {1: 'Yes', 2: 'No'}

value_map_likert_scales = {
    1: 'Strongly Disagree', 2: 'Disagree', 3: 'Neutral',
    4: 'Agree', 5: 'Strongly Agree'
}

LIKERT_COLS = [
    'detection_at_birth','scd_longevity','early_detection_importance',
    'need_immediate_result','enough_poct_info','poct_result_speed',
    'screening_recommendation','poct_recommendation',
    'dbs_for_validation','proper_treatment'
]
likert_cols_named = [c for c in LIKERT_COLS if c in df_questionnaire.columns]

def is_likert_series(s: pd.Series) -> bool:
    vals = pd.to_numeric(s.dropna(), errors='coerce')
    vals = vals[~vals.isna()]
    if vals.empty: return False
    u = set(vals.astype(int))
    return u.issubset({1,2,3,4,5}) and len(u) >= 3

likert_cols_auto = [c for c in df_questionnaire.columns if is_likert_series(df_questionnaire[c])]
likert_cols = sorted(set(likert_cols_named) | set(likert_cols_auto))

# --- Helper: map numeric codes → labels, preserving existing strings; then optional categorical ---
def apply_scale_preserve(df, col, scale_map, ordered=False, categories=None):
    if col not in df.columns:
        return
    # ensure column can hold strings
    df[col] = df[col].astype('object')

    # map only numeric-like entries
    nums = pd.to_numeric(df[col], errors='coerce')
    mask = nums.notna()
    mapped = nums.map(scale_map)
    df.loc[mask, col] = mapped

    # decide categories
    if categories is None:
        categories = list(scale_map.values())

    # cast to categorical only if all values are within categories
    non_null_vals = pd.Series(df[col].dropna().unique())
    if non_null_vals.empty or set(non_null_vals).issubset(set(categories)):
        dtype = pd.api.types.CategoricalDtype(categories=categories, ordered=ordered)
        df[col] = df[col].astype(dtype)

# --- Apply to non-Likert fields ---
apply_scale_preserve(
    df_questionnaire, 'sex_guardian',
    sex_guardian_scales, ordered=True, categories=['Male','Female']
)

apply_scale_preserve(
    df_questionnaire, 'guardian_relationship',
    guardian_relationship_scales, ordered=True,
    categories=[guardian_relationship_scales[i] for i in sorted(guardian_relationship_scales)]
)

apply_scale_preserve(
    df_questionnaire, 'scd_in_the_family',
    scd_in_the_family_scales, ordered=True, categories=['Yes','No',"I don't know"]
)

apply_scale_preserve(
    df_questionnaire, 'registry_willingness',
    registry_willingness_scales, ordered=True, categories=['Yes','No']
)

apply_scale_preserve(
    df_questionnaire, 'no_followup_reasons',
    no_followup_reasons_scales, ordered=True, categories=['Yes','No']
)

df_questionnaire[likert_cols] = (
    df_questionnaire[likert_cols].astype('object').replace(value_map_likert_scales)
)

likert_cat = pd.api.types.CategoricalDtype(
    categories=['Strongly Disagree','Disagree','Neutral','Agree','Strongly Agree'],
    ordered=True
)
for c in likert_cols:
    non_null_vals = pd.Series(df_questionnaire[c].dropna().unique())
    if non_null_vals.empty or set(non_null_vals).issubset(set(likert_cat.categories)):
        df_questionnaire[c] = df_questionnaire[c].astype(likert_cat)

# %%
s = (
    df_questionnaire['screening_date']
      .astype('string')          # handles categories / ints safely
      .str.strip()
      .str.replace(r'[./,-]', ' ', regex=True)   # normalize separators
      .str.replace(r'\s+', ' ', regex=True)
)

# First pass: generic parser with day-first
dt = pd.to_datetime(s, dayfirst=True, errors='coerce')

# Fallback A: 8-digit DDMMYYYY with no separators
mask8 = dt.isna() & s.str.fullmatch(r'\d{8}', na=False)
if mask8.any():
    s8 = s.loc[mask8].str.replace(r'(\d{2})(\d{2})(\d{4})', r'\1-\2-\3', regex=True)
    dt.loc[mask8] = pd.to_datetime(s8, dayfirst=True, errors='coerce')

# Fallback B: Excel serial dates (5–6 digits, e.g., 45210)
mask_serial = dt.isna() & s.str.fullmatch(r'\d{5,6}', na=False)
if mask_serial.any():
    base = pd.Timestamp('1899-12-30')
    dt.loc[mask_serial] = base + pd.to_timedelta(s.loc[mask_serial].astype(int), unit='D')

# ---------- 2) Plausibility window (adjust as needed) ----------
min_date = pd.Timestamp('2015-01-01')
max_date = pd.Timestamp.today().normalize() + pd.Timedelta(days=30)
dt = dt.where((dt >= min_date) & (dt <= max_date))

# ---------- 3) Optional: fall back to date_of_visit if screening_date failed ----------
if 'date_of_visit' in df_questionnaire.columns:
    dov = (
        df_questionnaire['date_of_visit']
          .astype('string').str.strip()
          .str.replace(r'[./,-]', ' ', regex=True)
          .str.replace(r'\s+', ' ', regex=True)
    )
    dov_dt = pd.to_datetime(dov, dayfirst=True, errors='coerce')
    dt = dt.fillna(dov_dt)

df_questionnaire['screening_date'] = dt

# %%
dob = pd.to_datetime(df_questionnaire['dob_guardian'], errors='coerce')
ref = pd.to_datetime(df_questionnaire['screening_date'], errors='coerce')

# If screening_date is missing, optionally fall back to date_of_visit / date_enrolled
if ref.isna().all() and 'date_of_visit' in df_questionnaire:
    ref = pd.to_datetime(df_questionnaire['date_of_visit'], errors='coerce').where(ref.isna(), ref)
if ref.isna().all() and 'date_enrolled' in df_questionnaire:
    ref = pd.to_datetime(df_questionnaire['date_enrolled'], errors='coerce').where(ref.isna(), ref)

td = ref - dob
age_years = td.dt.days / 365.25

# Keep plausible ages only (10–80 inclusive)
valid_mask = age_years.ge(10) & age_years.le(80)

dob_valid = dob.where(valid_mask)          # invalid ages -> NaT
age_valid = age_years.where(valid_mask)    # invalid ages -> NaN

# Write back
df_questionnaire['dob_guardian'] = dob_valid
# df_questionnaire['dob_guardian_iso'] = dob_valid.dt.strftime('%Y-%m-%d')
df_questionnaire['guardian_age'] = age_valid.round(1)
df_questionnaire.insert(5, 'guardian_age', df_questionnaire.pop('guardian_age'))

# %%
print(df_questionnaire.shape)
df_questionnaire.head()
# Out:
# (3983, 23)
#   record_id participant_id facility_id screening_date dob_guardian  \
# 0       GH1          ML001       GH001     2024-02-20   1996-12-10
# 1       GH2          ML002       GH001     2024-02-20          NaT
# 2       GH3          ML003       GH001     2024-02-20          NaT
# 3       GH4          ML004       GH001     2024-02-20          NaT
# 4       GH5          ML005       GH001     2024-02-21   1993-01-01
#
#    guardian_age sex_guardian guardian_relationship detection_at_birth  \
# 0          27.2       Female                Mother            Neutral
# 1           NaN       Female                Mother     Strongly Agree
# 2           NaN       Female                Mother            Neutral
# 3           NaN       Female                Mother     Strongly Agree
# 4          31.1       Female                Mother              Agree
#
#   scd_longevity early_detection_importance need_immediate_result  \
# 0      Disagree                      Agree        Strongly Agree
# 1      Disagree                      Agree        Strongly Agree
# 2      Disagree                      Agree        Strongly Agree
# 3         Agree             Strongly Agree              Disagree
# 4       Neutral                    Neutral               Neutral
#
#   enough_poct_info poct_result_speed screening_recommendation  \
# 0   Strongly Agree             Agree           Strongly Agree
# 1   Strongly Agree           Neutral           Strongly Agree
# 2   Strongly Agree    Strongly Agree           Strongly Agree
# 3   Strongly Agree             Agree           Strongly Agree
# 4            Agree             Agree                    Agree
#
#   poct_recommendation dbs_for_validation proper_treatment scd_in_the_family  \
# 0      Strongly Agree              Agree   Strongly Agree                No
# 1      Strongly Agree     Strongly Agree   Strongly Agree      I don't know
# 2      Strongly Agree              Agree   Strongly Agree                No
# 3      Strongly Agree     Strongly Agree   Strongly Agree                No
# 4               Agree              Agree            Agree                No
#
#   registry_willingness no_followup_reasons nofollowup_reason_specified country
# 0                  Yes                 Yes                         NaN   Ghana
# 1                  Yes                 Yes                         NaN   Ghana
# 2                  Yes                 Yes                         NaN   Ghana
# 3                  Yes                 Yes                         NaN   Ghana
# 4                  Yes                 Yes                         NaN   Ghana

# %% [markdown]
# ### EDA

# %%
df_questionnaire['country'].value_counts(dropna=False)
# Out:
# country
# Zimbabwe/Zambia    1000
# Ghana               999
# Uganda              980
# Tanzania            900
# Mali                104
# Name: count, dtype: int64

# %%
df_questionnaire['country'].value_counts(dropna=False)
# Out:
# country
# Zimbabwe/Zambia    1000
# Ghana               999
# Uganda              980
# Tanzania            900
# Mali                104
# Name: count, dtype: int64

# %%
# Count missing values in each column
missing_summary = df_questionnaire.isnull().sum()

# Filter for columns with missing values
missing_summary = missing_summary[missing_summary > 0].sort_values(ascending=False)

# Create a color gradient (blue shades)
colors = plt.cm.Blues(np.linspace(0.6, 1, len(missing_summary)))

# Adjust figure size for more vertical space
plt.figure(figsize=(14, 12))  # Increased height

# Plot missing values as a horizontal bar chart
missing_summary.plot(kind='barh', color=colors, width=0.8)  # Thicker bars

# Modern styling
plt.title('Missing Values Per Questionnaire Column (Guardian)', fontsize=14)
plt.xlabel('Number of Missing Values', fontsize=12)
plt.ylabel('Columns', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Remove top and right borders
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Remove borders around bars
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['bottom'].set_color('#cccccc')  # Light gray bottom border for subtle styling

# Improve layout
plt.tight_layout()

# Save the plot as a file
plt.savefig("figures/eda/missing_values_questionnaire.png", dpi=300, bbox_inches='tight')  # Save as PNG with high resolution

# Show the plot
plt.show()

# %%
country_remap = {
    'Zim_zam': 'Zimbabwe/Zambia'
    # add more remaps here if needed
}

# Build actual counts from df_questionnaire
actual_series = (
    df_questionnaire['country']
      .map(country_remap)
      .fillna(df_questionnaire['country'])
      .value_counts()
)

actual_df = actual_series.rename_axis('Country').reset_index(name='Actual')
actual_df
# Out:
#            Country  Actual
# 0  Zimbabwe/Zambia    1000
# 1            Ghana     999
# 2           Uganda     980
# 3         Tanzania     900
# 4             Mali     104

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# --- derive Actual from dataset ---
# Remap country labels from the dataset to display names
country_remap = {
    'Zim_zam': 'Zimbabwe/Zambia'
    # add more remaps here if needed
}

# Build actual counts from df_questionnaire
actual_series = (
    df_questionnaire['country']
      .map(country_remap)
      .fillna(df_questionnaire['country'])
      .value_counts()
)

actual_df = actual_series.rename_axis('Country').reset_index(name='Actual')

# --- targets (keep your goals) ---
target_data = {
    "Ghana": 1000,
    "Mali": 1000,
    "Nigeria": 2500,          # will show 0 actual if not present in data
    "Tanzania": 1000,
    "Uganda": 1000,
    "Zimbabwe/Zambia": 1000
}

# Desired order on the x-axis
order = ["Ghana", "Mali", "Nigeria", "Tanzania", "Uganda", "Zimbabwe/Zambia"]

# Assemble final plotting table (include all in `order`; fill missing actual with 0)
df = pd.DataFrame({"Country": order})
df = df.merge(actual_df, on="Country", how="left")
df["Actual"] = df["Actual"].fillna(0).astype(int)
df["Target"] = df["Country"].map(target_data)

# ---- Plot ----
x = np.arange(len(df["Country"]))
width = 0.35

fig, ax = plt.subplots(figsize=(12, 6))

bars1 = ax.bar(x - width/2, df["Actual"], width, label="Actual")
bars2 = ax.bar(x + width/2, df["Target"], width, label="Target")

for rect, cnt in zip(bars1, df["Actual"]):
    ax.text(rect.get_x() + rect.get_width()/2, rect.get_height() + max(df["Target"])*0.02,
            f"{cnt}", ha="center", va="bottom", fontsize=10)

for rect, cnt in zip(bars2, df["Target"]):
    ax.text(rect.get_x() + rect.get_width()/2, rect.get_height() + max(df["Target"])*0.02,
            f"{cnt}", ha="center", va="bottom", fontsize=10)

ax.grid(visible=False, which='both', axis='both')
ax.xaxis.grid(False)
ax.yaxis.grid(False)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_ylabel("Enrollment Counts", fontsize=12)
ax.set_title("Newborn Screening Enrollment: Actual vs Target", pad=25)
ax.title.set_y(1.02)  
ax.set_xticks(x)
ax.set_xticklabels(df["Country"], fontsize=12)
ax.legend(frameon=False)

plt.tight_layout()
plt.savefig("figures/eda/enrollment_actual_vs_target_clean.png", dpi=600, bbox_inches="tight")
plt.show()

# %%
df_questionnaire.head()
# Out:
#   record_id participant_id facility_id screening_date dob_guardian  \
# 0       GH1          ML001       GH001     2024-02-20   1996-12-10
# 1       GH2          ML002       GH001     2024-02-20          NaT
# 2       GH3          ML003       GH001     2024-02-20          NaT
# 3       GH4          ML004       GH001     2024-02-20          NaT
# 4       GH5          ML005       GH001     2024-02-21   1993-01-01
#
#    guardian_age sex_guardian guardian_relationship detection_at_birth  \
# 0          27.2       Female                Mother            Neutral
# 1           NaN       Female                Mother     Strongly Agree
# 2           NaN       Female                Mother            Neutral
# 3           NaN       Female                Mother     Strongly Agree
# 4          31.1       Female                Mother              Agree
#
#   scd_longevity early_detection_importance need_immediate_result  \
# 0      Disagree                      Agree        Strongly Agree
# 1      Disagree                      Agree        Strongly Agree
# 2      Disagree                      Agree        Strongly Agree
# 3         Agree             Strongly Agree              Disagree
# 4       Neutral                    Neutral               Neutral
#
#   enough_poct_info poct_result_speed screening_recommendation  \
# 0   Strongly Agree             Agree           Strongly Agree
# 1   Strongly Agree           Neutral           Strongly Agree
# 2   Strongly Agree    Strongly Agree           Strongly Agree
# 3   Strongly Agree             Agree           Strongly Agree
# 4            Agree             Agree                    Agree
#
#   poct_recommendation dbs_for_validation proper_treatment scd_in_the_family  \
# 0      Strongly Agree              Agree   Strongly Agree                No
# 1      Strongly Agree     Strongly Agree   Strongly Agree      I don't know
# 2      Strongly Agree              Agree   Strongly Agree                No
# 3      Strongly Agree     Strongly Agree   Strongly Agree                No
# 4               Agree              Agree            Agree                No
#
#   registry_willingness no_followup_reasons nofollowup_reason_specified country
# 0                  Yes                 Yes                         NaN   Ghana
# 1                  Yes                 Yes                         NaN   Ghana
# 2                  Yes                 Yes                         NaN   Ghana
# 3                  Yes                 Yes                         NaN   Ghana
# 4                  Yes                 Yes                         NaN   Ghana

# %%
df_questionnaire['country'].value_counts(dropna=False)
# Out:
# country
# Zimbabwe/Zambia    1000
# Ghana               999
# Uganda              980
# Tanzania            900
# Mali                104
# Name: count, dtype: int64

# %%
country_remap = {'Zim_zam': 'Zimbabwe/Zambia'}
dfp = df_questionnaire.copy()
dfp['Country'] = dfp['country'].map(country_remap).fillna(dfp['country'])

def _norm_sex(x):
    if pd.isna(x):
        return np.nan
    # numeric codes 0/1 → Male/Female
    sx = str(x).strip()
    if sx in ('0', '1'):
        return 'Male' if sx == '0' else 'Female'

    s = sx.lower()
    if s in ('m', 'male'):   return 'Male'
    if s in ('f', 'female'): return 'Female'
    return np.nan

dfp['sex_norm'] = dfp['sex_guardian'].apply(_norm_sex).astype('object')
dfp['sex_norm'] = dfp['sex_norm'].fillna('Missing')

counts = (
    dfp.groupby(['Country', 'sex_norm'])
       .size()
       .unstack(fill_value=0)
)

# Ensure expected columns exist and order them
for col in ['Female', 'Male', 'Missing']:
    if col not in counts.columns:
        counts[col] = 0
counts = counts[['Female', 'Male', 'Missing']]

# Desired country order on the grid
order = ["Ghana", "Mali", "Nigeria", "Tanzania", "Uganda", "Zimbabwe/Zambia"]
counts = counts.reindex(order, fill_value=0)

# --- plot pies (2x3 grid) ---
fig, axes = plt.subplots(2, 3, figsize=(14, 8))
axes = axes.flatten()

labels = ["Female", "Male", "Missing"]
wedges_for_legend = None

for i, country in enumerate(order):
    ax = axes[i]
    vals = counts.loc[country, labels].values
    total = vals.sum()

    if total == 0:
        ax.axis('off')
        ax.set_title(country, fontsize=14)
        ax.text(0.5, 0.5, "No data", ha="center", va="center", fontsize=12)
        continue

    wedges, texts, autotexts = ax.pie(
        vals, autopct="%1.0f%%", startangle=90, counterclock=False
    )
    ax.set_title(country, fontsize=14)

    if wedges_for_legend is None:
        wedges_for_legend = wedges  # capture handles for legend

# One global legend
if wedges_for_legend is not None:
    fig.legend(wedges_for_legend, labels, loc="lower center", ncol=3, frameon=False, fontsize=12)

plt.suptitle("Guardian Gender Distribution by Country", fontsize=16, y=1.04)
plt.tight_layout()
plt.savefig("figures/eda/guardian_sex_pies_combined_biglegend.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
country_remap = {'Zim_zam': 'Zimbabwe/Zambia'}

# Which guardian relationships to include (match your example)
REL_KEEP = ['Mother', 'Father', 'Grandparent']

# Desired country order on the x-axis
COUNTRY_ORDER = ["Ghana", "Mali", "Nigeria", "Tanzania", "Uganda", "Zimbabwe/Zambia"]

# --- Build counts from the dataset ---
dfp = df_questionnaire.copy()
dfp['Country'] = dfp['country'].map(country_remap).fillna(dfp['country'])

# Keep only the relationships you want to plot
mask = dfp['guardian_relationship'].isin(REL_KEEP)
counts = (
    dfp.loc[mask]
       .groupby(['Country', 'guardian_relationship'])
       .size()
       .unstack(fill_value=0)
)

# Ensure all three columns exist, in the desired order
for col in REL_KEEP:
    if col not in counts.columns:
        counts[col] = 0
counts = counts[REL_KEEP]

# Ensure all six countries appear, fill with 0 if missing
counts = counts.reindex(COUNTRY_ORDER, fill_value=0)

# --- Convert to percentages across each country (row) ---
row_totals = counts.sum(axis=1)
df_perc = (counts.div(row_totals.replace(0, np.nan), axis=0) * 100).fillna(0.0)

# Transpose so relationships are on Y axis
df_perc_T = df_perc.T

# --- Plot heatmap ---
plt.figure(figsize=(10, 4))
ax = sns.heatmap(
    df_perc_T, annot=True, fmt=".1f", cmap="Blues",
    cbar_kws={'label': 'Percentage (%)'}
)

ax.set_title("Guardian Relationship by Country (Proportions)", fontsize=14, pad=20)
ax.set_ylabel("Guardian Relationship", fontsize=12)
ax.set_xlabel("Country", fontsize=12, labelpad=10)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0)

plt.tight_layout()
plt.savefig("figures/eda/guardian_relationship_heatmap_horizontal_labels.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# --- Map item codes → dataframe columns ---
code_to_col = {
    "scd_detect_birth":        "detection_at_birth",
    "scd_live_long":           "scd_longevity",
    "scd_early_detection":     "early_detection_importance",
    "test_result_immediate":   "need_immediate_result",
    "poc_info_access":         "enough_poct_info",
    "poc_faster_result":       "poct_result_speed",
    "recommend_scd_screening": "screening_recommendation",
    "recommend_poc":           "poct_recommendation",
    "dbs_acceptable":          "dbs_for_validation",
    "seek_treatment":          "proper_treatment",
}

# Only keep items whose columns exist
code_to_col = {k: v for k, v in code_to_col.items() if v in df_questionnaire.columns}

likert_levels = ["Strongly Disagree", "Disagree", "Neutral", "Agree", "Strongly Agree"]

# --- Build counts per item (across all countries) ---
rows = []
for code, col in code_to_col.items():
    s = df_questionnaire[col]
    row = {"Item": code}
    # counts for each Likert level
    total_non_missing = s.notna().sum()
    for lvl in likert_levels:
        row[lvl] = (s == lvl).sum()
    row["Missing"] = s.isna().sum()
    row["_total_non_missing"] = total_non_missing
    rows.append(row)

df_counts = pd.DataFrame(rows)

# --- Convert to percentages (excluding missing) ---
df_percent = df_counts.copy()
for lvl in likert_levels:
    df_percent[lvl] = np.where(
        df_counts["_total_non_missing"] > 0,
        df_counts[lvl] / df_counts["_total_non_missing"] * 100.0,
        0.0
    )

# --- Order items & reverse so first appears at top ---
order = [
    "scd_detect_birth", "scd_live_long", "scd_early_detection",
    "test_result_immediate", "poc_info_access", "poc_faster_result",
    "recommend_scd_screening", "recommend_poc",
    "dbs_acceptable", "seek_treatment"
]
order = [c for c in order if c in df_percent["Item"].values]  # guard if some missing
df_percent = df_percent.set_index("Item").loc[order]
df_percent = df_percent.iloc[::-1]  # put first item at top

# --- Plot ---
fig, ax = plt.subplots(figsize=(12, 7))

colors = ["#d73027", "#fc8d59", "#ffffbf", "#91bfdb", "#4575b4"]  # same palette
df_percent[likert_levels].plot(kind="barh", stacked=True, ax=ax, color=colors)

ax.set_xlabel("Percentage of Responses", fontsize=12)
ax.set_ylabel("Survey Item", fontsize=12)
ax.set_title("Guardians: Survey Responses Across All Countries", fontsize=14, pad=15)

# Clean up
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.grid(False)  # ensure no grid lines

# Legend (no title)
ax.legend(title=None, bbox_to_anchor=(1.05, 1), loc="upper left", frameon=False)

plt.tight_layout()
plt.savefig("figures/eda/likert_combined_all_countries_top_scd_detect_birth.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
CODE_TO_COL = {
    "scd_detect_birth":        "detection_at_birth",
    "scd_live_long":           "scd_longevity",
    "scd_early_detection":     "early_detection_importance",
    "test_result_immediate":   "need_immediate_result",
    "poc_info_access":         "enough_poct_info",
    "poc_faster_result":       "poct_result_speed",
    "recommend_scd_screening": "screening_recommendation",
    "recommend_poc":           "poct_recommendation",
    "dbs_acceptable":          "dbs_for_validation",
    "seek_treatment":          "proper_treatment",
}

ORDER = [
    "scd_detect_birth", "scd_live_long", "scd_early_detection",
    "test_result_immediate", "poc_info_access", "poc_faster_result",
    "recommend_scd_screening", "recommend_poc", "dbs_acceptable", "seek_treatment"
]

LIKERT_COLS = ["Strongly Disagree", "Disagree", "Neutral", "Agree", "Strongly Agree"]
COLORS = ["#d73027", "#fc8d59", "#ffffbf", "#91bfdb", "#4575b4"]

# Countries to plot in your layout order
COUNTRIES = ["Mali", "Nigeria", "Tanzania", "Uganda", "Zimbabwe/Zambia"]

# Remap dataset country labels to display names
COUNTRY_REMAP = {"Zim_zam": "Zimbabwe/Zambia"}

# -------------------- helpers --------------------
def likert_percent_for_country(dfq: pd.DataFrame, country_label: str) -> pd.DataFrame:
    """
    Compute a Likert % table (rows=items, cols=LIKERT_COLS) for a single country.
    Percentages exclude missing (NaN). Returns rows in ORDER (reversed for barh).
    """
    # Prep: map Zim_zam and select country
    dfp = dfq.copy()
    dfp["Country"] = dfp["country"].map(COUNTRY_REMAP).fillna(dfp["country"])
    sub = dfp[dfp["Country"] == country_label]

    # If no rows for this country, return empty marker
    if sub.empty:
        return pd.DataFrame(columns=LIKERT_COLS, index=list(reversed(ORDER)))

    rows = []
    for code, col in CODE_TO_COL.items():
        if col not in sub.columns:
            # column missing -> treat as 0% everywhere
            rows.append({"Item": code, **{k: 0.0 for k in LIKERT_COLS}, "_n": 0})
            continue
        s = sub[col]
        n_nonmiss = s.notna().sum()
        counts = {lvl: int((s == lvl).sum()) for lvl in LIKERT_COLS}
        if n_nonmiss > 0:
            pct = {lvl: counts[lvl] / n_nonmiss * 100.0 for lvl in LIKERT_COLS}
        else:
            pct = {lvl: 0.0 for lvl in LIKERT_COLS}
        row = {"Item": code, **pct, "_n": n_nonmiss}
        rows.append(row)

    dfpct = pd.DataFrame(rows).set_index("Item").loc[ORDER, LIKERT_COLS]
    # reverse for barh so first item appears at the top
    return dfpct.iloc[::-1]

# -------------------- build per-country tables --------------------
dfs = {cty: likert_percent_for_country(df_questionnaire, cty) for cty in COUNTRIES}

# -------------------- plot (manual layout; same as your example) --------------------
fig = plt.figure(figsize=(17, 10))

# Top row (3)
ax1 = fig.add_axes([0.05, 0.55, 0.3, 0.35])   # Mali
ax2 = fig.add_axes([0.38, 0.55, 0.3, 0.35])   # Nigeria
ax3 = fig.add_axes([0.71, 0.55, 0.3, 0.35])   # Tanzania

# Bottom row (2 centered)
ax4 = fig.add_axes([0.22, 0.08, 0.3, 0.35])   # Uganda
ax5 = fig.add_axes([0.55, 0.08, 0.3, 0.35])   # Zimbabwe/Zambia

axes = [ax1, ax2, ax3, ax4, ax5]

for ax, country in zip(axes, COUNTRIES):
    dff = dfs[country]
    if dff.empty or dff.to_numpy().sum() == 0:
        # No data panel
        ax.axis("off")
        ax.set_title(country, fontsize=17)
        ax.text(0.5, 0.5, "No data", ha="center", va="center", fontsize=14)
        continue

    dff[LIKERT_COLS].plot(kind="barh", stacked=True, ax=ax, color=COLORS, legend=False)

    ax.set_title(country, fontsize=17)
    ax.set_xlabel("Percentage", fontsize=16, labelpad=10)
    ax.tick_params(axis="y", labelsize=15)

    # Show y-axis labels only on far-left of each row (Mali, Uganda)
    if country not in ["Mali", "Uganda"]:
        ax.set_yticklabels([])
        ax.set_ylabel("")
    else:
        ax.set_ylabel("Survey Item", fontsize=16)

    # Clean look + no grid lines
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.grid(False)

# One shared legend at the bottom
fig.legend(LIKERT_COLS, loc="lower center", ncol=5, frameon=False, fontsize=17,
           bbox_to_anchor=(0.5, -0.06))

fig.suptitle("Survey Responses by Country (Likert %)", y=0.98, fontsize=19)
plt.savefig("likert_subplots_centered_manual_from_dataset.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
print(df_questionnaire.shape)
df_questionnaire.head()
# Out:
# (3983, 23)
#   record_id participant_id facility_id screening_date dob_guardian  \
# 0       GH1          ML001       GH001     2024-02-20   1996-12-10
# 1       GH2          ML002       GH001     2024-02-20          NaT
# 2       GH3          ML003       GH001     2024-02-20          NaT
# 3       GH4          ML004       GH001     2024-02-20          NaT
# 4       GH5          ML005       GH001     2024-02-21   1993-01-01
#
#    guardian_age sex_guardian guardian_relationship detection_at_birth  \
# 0          27.2       Female                Mother            Neutral
# 1           NaN       Female                Mother     Strongly Agree
# 2           NaN       Female                Mother            Neutral
# 3           NaN       Female                Mother     Strongly Agree
# 4          31.1       Female                Mother              Agree
#
#   scd_longevity early_detection_importance need_immediate_result  \
# 0      Disagree                      Agree        Strongly Agree
# 1      Disagree                      Agree        Strongly Agree
# 2      Disagree                      Agree        Strongly Agree
# 3         Agree             Strongly Agree              Disagree
# 4       Neutral                    Neutral               Neutral
#
#   enough_poct_info poct_result_speed screening_recommendation  \
# 0   Strongly Agree             Agree           Strongly Agree
# 1   Strongly Agree           Neutral           Strongly Agree
# 2   Strongly Agree    Strongly Agree           Strongly Agree
# 3   Strongly Agree             Agree           Strongly Agree
# 4            Agree             Agree                    Agree
#
#   poct_recommendation dbs_for_validation proper_treatment scd_in_the_family  \
# 0      Strongly Agree              Agree   Strongly Agree                No
# 1      Strongly Agree     Strongly Agree   Strongly Agree      I don't know
# 2      Strongly Agree              Agree   Strongly Agree                No
# 3      Strongly Agree     Strongly Agree   Strongly Agree                No
# 4               Agree              Agree            Agree                No
#
#   registry_willingness no_followup_reasons nofollowup_reason_specified country
# 0                  Yes                 Yes                         NaN   Ghana
# 1                  Yes                 Yes                         NaN   Ghana
# 2                  Yes                 Yes                         NaN   Ghana
# 3                  Yes                 Yes                         NaN   Ghana
# 4                  Yes                 Yes                         NaN   Ghana

# %%
df_questionnaire.to_excel('../data/clean/clean.xlsx', index=False)
